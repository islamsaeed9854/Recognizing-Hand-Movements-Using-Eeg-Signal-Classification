# %% [markdown]
# ## Arm Reaching (MI Session 1)

# %%
import os
import glob
import numpy as np
import mne
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from google.colab import drive
# drive.mount('/content/drive')
from scipy.io import loadmat
from scipy.signal import butter, lfilter
warnings.filterwarnings('ignore')

# %% [markdown]
# ### BrainVision (.vhdr, .vmrk, .eeg)
#
# The BrainVision file format consists of three separate files:
#
# 1. A text header file (.vhdr) containing meta data.
#
# 2. A text marker file (.vmrk) containing information about events in the data.
#
# 3. A binary data file (.eeg) containing the voltage values of the EEG.

# %%
folder_path=r'D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI'
folder_files=os.listdir(folder_path)
for i in folder_files:
    print(i)
# Out:
# session1_sub10_reaching_MI.eeg
# session1_sub10_reaching_MI.vhdr
# session1_sub10_reaching_MI.vmrk
# session1_sub1_reaching_MI.eeg
# session1_sub1_reaching_MI.vhdr
# session1_sub1_reaching_MI.vmrk
# session1_sub2_reaching_MI.eeg
# session1_sub2_reaching_MI.vhdr
# session1_sub2_reaching_MI.vmrk
# session1_sub3_reaching_MI.eeg
# session1_sub3_reaching_MI.vhdr
# session1_sub3_reaching_MI.vmrk
# session1_sub4_reaching_MI.eeg
# session1_sub4_reaching_MI.vhdr
# session1_sub4_reaching_MI.vmrk
# session1_sub5_reaching_MI.eeg
# session1_sub5_reaching_MI.vhdr
# session1_sub5_reaching_MI.vmrk
# session1_sub6_reaching_MI.eeg
# session1_sub6_reaching_MI.vhdr
# session1_sub6_reaching_MI.vmrk
# session1_sub7_reaching_MI.eeg
# session1_sub7_reaching_MI.vhdr
# session1_sub7_reaching_MI.vmrk
# session1_sub8_reaching_MI.eeg
# session1_sub8_reaching_MI.vhdr
# session1_sub8_reaching_MI.vmrk
# session1_sub9_reaching_MI.eeg
# session1_sub9_reaching_MI.vhdr
# session1_sub9_reaching_MI.vmrk

# %%
eeg,vhdr,vmrk = [],[],[]

for i in folder_files:
    file=folder_path+'\\'+i
    if '.eeg' in file:
        eeg.append(file) 
    elif '.vhdr' in file:
        vhdr.append(file) 
    else:
        vmrk.append(file)
        
for i in range(0,len(eeg)):
    print(eeg[i]+'\n'+vhdr[i]+'\n'+vmrk[i]+'\n')
# Out:
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.vmrk

# %% [markdown]
# ### Read Raw Signals

# %%
raw = mne.io.read_raw_brainvision(vhdr[1], misc='auto', scale=1.0, preload=True, verbose=None)
raw # OR raw.info
# Out:
# Extracting parameters from D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.vhdr...
# Setting channel info structure...
# Reading 0 ... 10055299  =      0.000 ...  4022.120 secs...
# <RawBrainVision | session1_sub1_reaching_MI.eeg, 71 x 10055300 (4022.1 s), ~5.32 GB, data loaded>

# %%
raw.set_channel_types(mapping={'hEOG_L': 'eog', 'hEOG_R': 'eog', 'vEOG_U': 'eog', 'vEOG_D': 'eog'})
raw.set_channel_types(mapping={'EMG_1': 'emg', 'EMG_2': 'emg', 'EMG_3': 'emg', 'EMG_4': 'emg', 'EMG_5': 'emg', 'EMG_6': 'emg', 'EMG_ref': 'emg'})
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, AFz, F7, F5, F3, F1, Fz, FT7, FC5, FC3, FC1, T7, ...
#  chs: 60 EEG, 4 EOG, 7 EMG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 1250.0 Hz
#  meas_date: 2019-08-22 11:48:44 UTC
#  nchan: 71
#  projs: []
#  sfreq: 2500.0 Hz
# >

# %%
print('bad channels:', raw.info['bads'])  # chs marked "bad" during acquisition
print(raw.info['sfreq'], 'Hz')            # sampling frequency
print(raw.info['description'], '\n')      # miscellaneous acquisition info
# Out:
# bad channels: []
# 2500.0 Hz
# None

# %%
raw.plot(n_channels=71);
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ### For One Session, Each Subject Do :
#  - 50 Trials For Each Class : 50 x 6 ( Classes ) = Total 300 Trials
#
#  - Each Trial has Time Duration 7s ( 3s Visual Cue + 4s Movement Implementation )
#
#  - and There Are 300 Rest Periods Between Those Trials ( Each Rest Period has Time Duration 4s )
#
#  - Finally,
#       Total Session Time = 50 x 6 x 7 + 300 x 4 = almost 3300 seconds

# %%
print('First Time : ',raw.first_time)
print('Last Time  : ',raw._last_time)
# Out:
# First Time :  0.0
# Last Time  :  4022.1196

# %% [markdown]
# - Therefore, The Total Count of Samples For All Trials : 300 ( Trials ) x 7s x 2500 (Fs) + 300 (Rests) x 4s x 2500 (Fs) is almost 8,250,000

# %%
print('Total Samples : ',len(raw))
print('Start : ',raw._first_samps) 
print('End : ',raw._last_samps)
# Out:
# Total Samples :  10055300
# Start :  [0]
# End :  [10055299]

# %% [markdown]
# ### time_as_index()
# - Convert time to indices ( time ( s ) : index ( 0-based ) )
#
# - Input : List of numbers or a number representing points in time.
#
# - Return : Indices relative to first_samp corresponding to the times supplied.

# %%
print(raw.time_as_index([1, 2, 3, 4, 5]), '\n')
print(np.diff(raw.time_as_index([1, 2, 3])))
# Out:
# [ 2500  5000  7500 10000 12500]
#
# [2500 2500]

# %% [markdown]
# ### Electrodes Handling :
# ### pick_types() : Picking Some Type of Signals and Ignore Others.
# ### pick_channels() : pick channels by name.
# ### drop_channels() : method to remove channels by name.

# %%
# this piece of code does not make changes in this case, only for learn

# eeg_and_eog = raw.copy().pick_types(emg=False, eeg=True, eog=True)
# print(len(raw.ch_names), '→', len(eeg_and_eog.ch_names))

# %% [markdown]
# ### We Will Select Channels According to International Standard 10–20 system
#
# <img src="The-location-map-of-32-channels-cap-The-electrodes-can-be-divided-into-3-groups.png" style="width:400px;hight:400;"/>

# %%
print(raw.ch_names)
# Out:
# ['Fp1', 'AF7', 'AF3', 'AFz', 'F7', 'F5', 'F3', 'F1', 'Fz', 'FT7', 'FC5', 'FC3', 'FC1', 'T7', 'C5', 'C3', 'C1', 'Cz', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'P7', 'P5', 'P3', 'P1', 'Pz', 'PO7', 'PO3', 'POz', 'hEOG_L', 'hEOG_R', 'vEOG_U', 'vEOG_D', 'Fp2', 'AF4', 'AF8', 'F2', 'F4', 'F6', 'F8', 'FC2', 'FC4', 'FC6', 'FT8', 'C2', 'C4', 'C6', 'T8', 'CP2', 'CP4', 'CP6', 'TP8', 'P2', 'P4', 'P6', 'P8', 'PO4', 'PO8', 'O1', 'Oz', 'O2', 'Iz', 'EMG_1', 'EMG_2', 'EMG_3', 'EMG_4', 'EMG_5', 'EMG_6', 'EMG_ref']

# %%
selected_channels = ["Fp1", "AF3","F7","F3","FC1","FC5","T7","C3","CP1","CP5","P7","P3", "PO3", "O1",  # Brain Left Side
                     "Fz","Cz","Pz","Oz",                                                              # Brain Mid
                     "O2","FC2","F4","F8","AF4","Fp2","C4", "T8","FC6","CP2","PO4","P4","P8","CP6",    # Brain Right Side   
                     "hEOG_L", "hEOG_R", "vEOG_U", "vEOG_D"]                                           # EOG Channels

# %%
raw.pick_channels(ch_names=selected_channels)
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage)
print(len(raw.ch_names))
# Out:
# 36

# %%
raw.plot(n_channels=36);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.plot_sensors(show_names=True,sphere=0.11);
fig = montage.plot(kind='3d',show=False)
fig = fig.gca().view_init(azim=70, elev=15)  # set view angle for tutorial
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.

# %% [markdown]
# ### Plotting spectral density of continuous data
#
# - To visualize the frequency content of continuous data
#
# - the Raw object provides a compute_psd() method to compute spectral density and the resulting Spectrum object has a plot() method

# %%
spectrum = raw.compute_psd()
spectrum.plot(average=True)
# Out:
# Effective window size : 0.102 (s)
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ### plot spectral power estimates across sensors as a scalp topography
# - will compute power based on magnetometer channels (if present), and will plot the power estimates on a dB-like log-scale.

# %%
spectrum.plot_topomap(bands={'Alpha (8-12 Hz)': (8, 12), 'Beta (12-30 Hz)': (12, 30),'Gamma (30-45 Hz)': (30,45)});

# %% [markdown]
# ### plot the PSD for every sensor on its own axes
# - the axes arranged spatially to correspond to sensor locations in space.

# %%
spectrum.plot_topo();

# %% [markdown]
# ### Bandpass Filtering the Data
# - Filtering to remove slow drift.
# - Before we run the ICA, an important step is filtering the data to remove low-frequency drifts, which can negatively affect the quality of the ICA fit.

# %%
raw.filter(l_freq=8,h_freq=30, method='iir', iir_params=dict(order=4, ftype='butter', output='sos'), phase='zero-double')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 30.00 Hz: -6.02, -6.02 dB
# <RawBrainVision | session1_sub1_reaching_MI.eeg, 36 x 10055300 (4022.1 s), ~2.70 GB, data loaded>

# %%
raw.plot(n_channels=36);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
spectrum = raw.compute_psd()
spectrum.plot(average=True)
# Out:
# Effective window size : 0.102 (s)
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ### Refrencing EEG

# %%
# Average reference. This is normally added by default, but can also be added
# explicitly.
raw.set_eeg_reference(ref_channels='average')
raw.plot(n_channels=36);
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# ### Detect Ocular artifacts (EOG)

# - MNE-Python includes functions for detecting and extracting ocular artifacts: find_eog_events() and create_eog_epochs(). Once again we’ll use the higher-level convenience function that automatically finds the artifacts and extracts them in to an Epochs object in one step. 

# - ocular artifacts are usually most prominent in the EEG channels.

# - note that there are many fewer blinks than heartbeats, which makes the image plots appear somewhat blocky.

# %%
# # baseline : The electrical signal from a sensor when no measured variable is present. Often referred to the output at no-load condition
# eog_epochs = mne.preprocessing.create_eog_epochs(raw,ch_name=["hEOG_L", "hEOG_R", "vEOG_U", "vEOG_D"], baseline=(-0.5, -0.2))
# eog_epochs.plot_image(combine='mean');
# eog_epochs.average().plot_joint();

# %%
# eog_epochs

# %%
# ### Repairing artifacts with regression --Raw Data--
# Remove EOG artifact signals from other channels by regression.

# %%
# weights = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(raw)

# %%
# fig = weights.plot(vlim=(None, 0.4))  # regression coefficients / weights as topomap
# fig.set_size_inches(3, 2)

# %%
# # Fit the regression model
# raw_clean = weights.apply(raw, copy=False)

# # Show the filter weights in a topomap
# weights.plot();

# %%
# ### Repairing artifacts with ICA
# Note : ICA fitting is not deterministic (e.g., the components may get a sign flip on different runs, or may not always be returned in the same order), so we’ll also specify a random seed so that we get identical results each time this tutorial is built by our web servers

# %%
# ica = mne.preprocessing.ICA(n_components=32, max_iter='auto',random_state=0,method='infomax')
# ica.fit(raw.copy())

# %%
# ica.plot_components();

# %%
# # use automatic detection
# bad_indx,scores = ica.find_bads_eog(raw,ch_name=["hEOG_L","hEOG_R","vEOG_U","vEOG_D"],threshold=3,)
# print(bad_indx)

# %%
# raw.plot(n_channels=32);

# %%
# ica.exclude = bad_indx
# ica.apply(raw.copy(),exclude=ica.exclude).plot();

# %%
# ica.apply(raw,exclude=ica.exclude)

# %% [markdown]
# ### Read Events & Epoching

# %%
events = mne.events_from_annotations(raw)
# Out:
# Used Annotations descriptions: ['Comment/actiCAP Active Shield On', 'New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S  3', 'Stimulus/S  4', 'Stimulus/S  5', 'Stimulus/S  6', 'Stimulus/S  8', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 14', 'Stimulus/S 21', 'Stimulus/S 31', 'Stimulus/S 41', 'Stimulus/S 51', 'Stimulus/S 61']

# %%
list(events[0])
# Out:
# [array([    0,     0, 99999]),
#  array([    0,     0, 10001]),
#  array([74444,     0,    13]),
#  array([84522,     0,     1]),
#  array([92039,     0,    11]),
#  array([102086,      0,      8]),
#  array([112162,      0,      6]),
#  array([119674,      0,     61]),
#  array([129717,      0,      8]),
#  array([139803,      0,      4]),
#  array([147313,      0,     41]),
#  array([157360,      0,      8]),
#  array([167434,      0,      3]),
#  array([174944,      0,     31]),
#  array([184986,      0,      8]),
#  array([195071,      0,      1]),
#  array([202582,      0,     11]),
#  array([212626,      0,      8]),
#  array([222696,      0,      2]),
#  array([230206,      0,     21]),
#  array([240248,      0,      8]),
#  array([250323,      0,      2]),
#  array([257833,      0,     21]),
#  array([267875,      0,      8]),
#  array([277950,      0,      1]),
#  array([285460,      0,     11]),
#  array([295502,      0,      8]),
#  array([305580,      0,      6]),
#  array([313090,      0,     61]),
#  array([323132,      0,      8]),
#  array([333204,      0,      2]),
#  array([340714,      0,     21]),
#  array([350756,      0,      8]),
#  array([360828,      0,      4]),
#  array([368338,      0,     41]),
#  array([378380,      0,      8]),
#  array([388453,      0,      4]),
#  array([395963,      0,     41]),
#  array([406005,      0,      8]),
#  array([416081,      0,      1]),
#  array([423591,      0,     11]),
#  array([433633,      0,      8]),
#  array([443705,      0,      4]),
#  array([451215,      0,     41]),
#  array([461257,      0,      8]),
#  array([471327,      0,      2]),
#  array([478838,      0,     21]),
#  array([488880,      0,      8]),
#  array([498953,      0,      3]),
#  array([506462,      0,     31]),
#  array([516505,      0,      8]),
#  array([526585,      0,      3]),
#  array([534095,      0,     31]),
#  array([544142,      0,      8]),
#  array([554224,      0,      3]),
#  array([561734,      0,     31]),
#  array([571777,      0,      8]),
#  array([581855,      0,      6]),
#  array([589365,      0,     61]),
#  array([599408,      0,      8]),
#  array([609487,      0,      4]),
#  array([616999,      0,     41]),
#  array([627045,      0,      8]),
#  array([637127,      0,      4]),
#  array([644636,      0,     41]),
#  array([654680,      0,      8]),
#  array([664760,      0,      2]),
#  array([672272,      0,     21]),
#  array([682316,      0,      8]),
#  array([692391,      0,      3]),
#  array([699900,      0,     31]),
#  array([709944,      0,      8]),
#  array([720014,      0,      4]),
#  array([727518,      0,     41]),
#  array([737547,      0,      8]),
#  array([747618,      0,      6]),
#  array([755127,      0,     61]),
#  array([765172,      0,      8]),
#  array([775245,      0,      4]),
#  array([782752,      0,     41]),
#  array([792800,      0,      8]),
#  array([802876,      0,      2]),
#  array([810383,      0,     21]),
#  array([820426,      0,      8]),
#  array([830508,      0,      1]),
#  array([838020,      0,     11]),
#  array([848068,      0,      8]),
#  array([858147,      0,      5]),
#  array([865658,      0,     51]),
#  array([875700,      0,      8]),
#  array([885773,      0,      5]),
#  array([893283,      0,     51]),
#  array([903326,      0,      8]),
#  array([913396,      0,      4]),
#  array([920906,      0,     41]),
#  array([930965,      0,      8]),
#  array([941038,      0,      4]),
#  array([948545,      0,     41]),
#  array([958591,      0,      8]),
#  array([968667,      0,      5]),
#  array([976177,      0,     51]),
#  array([986219,      0,      8]),
#  array([996297,      0,      6]),
#  array([1003810,       0,      61]),
#  array([1013854,       0,       8]),
#  array([1023933,       0,       3]),
#  array([1031440,       0,      31]),
#  array([1041480,       0,       8]),
#  array([1051555,       0,       6]),
#  array([1059063,       0,      61]),
#  array([1069102,       0,       8]),
#  array([1079178,       0,       3]),
#  array([1086685,       0,      31]),
#  array([1096725,       0,       8]),
#  array([1106794,       0,       5]),
#  array([1114304,       0,      51]),
#  array([1124349,       0,       8]),
#  array([1134421,       0,       4]),
#  array([1141930,       0,      41]),
#  array([1151971,       0,       8]),
#  array([1162040,       0,       3]),
#  array([1169547,       0,      31]),
#  array([1179590,       0,       8]),
#  array([1189667,       0,       4]),
#  array([1197176,       0,      41]),
#  array([1207216,       0,       8]),
#  array([1217293,       0,       5]),
#  array([1224805,       0,      51]),
#  array([1234851,       0,       8]),
#  array([1244923,       0,       2]),
#  array([1252431,       0,      21]),
#  array([1262471,       0,       8]),
#  array([1272543,       0,       6]),
#  array([1280052,       0,      61]),
#  array([1290094,       0,       8]),
#  array([1300169,       0,       4]),
#  array([1307676,       0,      41]),
#  array([1317716,       0,       8]),
#  array([1327784,       0,       6]),
#  array([1335292,       0,      61]),
#  array([1345332,       0,       8]),
#  array([1355410,       0,       5]),
#  array([1362917,       0,      51]),
#  array([1372957,       0,       8]),
#  array([1383027,       0,       5]),
#  array([1390537,       0,      51]),
#  array([1400580,       0,       8]),
#  array([1410657,       0,       5]),
#  array([1418166,       0,      51]),
#  array([1428207,       0,       8]),
#  array([1438274,       0,       3]),
#  array([1445782,       0,      31]),
#  array([1455821,       0,       8]),
#  array([1465894,       0,       1]),
#  array([1473402,       0,      11]),
#  array([1483446,       0,       8]),
#  array([1493515,       0,       1]),
#  array([1501023,       0,      11]),
#  array([1511067,       0,       8]),
#  array([1521141,       0,       2]),
#  array([1528644,       0,      21]),
#  array([1538689,       0,       8]),
#  array([1548758,       0,       6]),
#  array([1556266,       0,      61]),
#  array([1566306,       0,       8]),
#  array([1576371,       0,       6]),
#  array([1583880,       0,      61]),
#  array([1593918,       0,       8]),
#  array([1603988,       0,       4]),
#  array([1611496,       0,      41]),
#  array([1621538,       0,       8]),
#  array([1631615,       0,       6]),
#  array([1639121,       0,      61]),
#  array([1649160,       0,       8]),
#  array([1659234,       0,       5]),
#  array([1666741,       0,      51]),
#  array([1676781,       0,       8]),
#  array([1686851,       0,       2]),
#  array([1694358,       0,      21]),
#  array([1704401,       0,       8]),
#  array([1714473,       0,       3]),
#  array([1721980,       0,      31]),
#  array([1732026,       0,       8]),
#  array([1742101,       0,       6]),
#  array([1749608,       0,      61]),
#  array([1759649,       0,       8]),
#  array([1769720,       0,       6]),
#  array([1777227,       0,      61]),
#  array([1787275,       0,       8]),
#  array([1797350,       0,       2]),
#  array([1804859,       0,      21]),
#  array([1814902,       0,       8]),
#  array([1824977,       0,       2]),
#  array([1832487,       0,      21]),
#  array([1842530,       0,       8]),
#  array([1852616,       0,       5]),
#  array([1860126,       0,      51]),
#  array([1870167,       0,       8]),
#  array([1880237,       0,       6]),
#  array([1887745,       0,      61]),
#  array([1897785,       0,       8]),
#  array([1907855,       0,       2]),
#  array([1915363,       0,      21]),
#  array([1925403,       0,       8]),
#  array([1935482,       0,       6]),
#  array([1942989,       0,      61]),
#  array([1953030,       0,       8]),
#  array([1963107,       0,       3]),
#  array([1970614,       0,      31]),
#  array([1980655,       0,       8]),
#  array([1990728,       0,       3]),
#  array([1998236,       0,      31]),
#  array([2008276,       0,       8]),
#  array([2018359,       0,       2]),
#  array([2025869,       0,      21]),
#  array([2035910,       0,       8]),
#  array([2045980,       0,       3]),
#  array([2053487,       0,      31]),
#  array([2063528,       0,       8]),
#  array([2073606,       0,       3]),
#  array([2081115,       0,      31]),
#  array([2091156,       0,       8]),
#  array([2101228,       0,       6]),
#  array([2108735,       0,      61]),
#  array([2118775,       0,       8]),
#  array([2128847,       0,       6]),
#  array([2136357,       0,      61]),
#  array([2146398,       0,       8]),
#  array([2156476,       0,       2]),
#  array([2163983,       0,      21]),
#  array([2174024,       0,       8]),
#  array([2184103,       0,       1]),
#  array([2191612,       0,      11]),
#  array([2201653,       0,       8]),
#  array([2211725,       0,       6]),
#  array([2219235,       0,      61]),
#  array([2229276,       0,       8]),
#  array([2239346,       0,       3]),
#  array([2246853,       0,      31]),
#  array([2256893,       0,       8]),
#  array([2266973,       0,       1]),
#  array([2274482,       0,      11]),
#  array([2284525,       0,       8]),
#  array([2294600,       0,       5]),
#  array([2302110,       0,      51]),
#  array([2312151,       0,       8]),
#  array([2322220,       0,       2]),
#  array([2329727,       0,      21]),
#  array([2339767,       0,       8]),
#  array([2349846,       0,       5]),
#  array([2357356,       0,      51]),
#  array([2367396,       0,       8]),
#  array([2377470,       0,       2]),
#  array([2384980,       0,      21]),
#  array([2395021,       0,       8]),
#  array([2405097,       0,       3]),
#  array([2412606,       0,      31]),
#  array([2422646,       0,       8]),
#  array([2432715,       0,       1]),
#  array([2440222,       0,      11]),
#  array([2450262,       0,       8]),
#  array([2460338,       0,       6]),
#  array([2467845,       0,      61]),
#  array([2477885,       0,       8]),
#  array([2487964,       0,       3]),
#  array([2495472,       0,      31]),
#  array([2505513,       0,       8]),
#  array([2515594,       0,       6]),
#  array([2523104,       0,      61]),
#  array([2533144,       0,       8]),
#  array([2543214,       0,       1]),
#  array([2550721,       0,      11]),
#  array([2560761,       0,       8]),
#  array([2570840,       0,       5]),
#  array([2578347,       0,      51]),
#  array([2588387,       0,       8]),
#  array([2598463,       0,       5]),
#  array([2605973,       0,      51]),
#  array([2616015,       0,       8]),
#  array([2626092,       0,       5]),
#  array([2633602,       0,      51]),
#  array([2643644,       0,       8]),
#  array([2653715,       0,       3]),
#  array([2661225,       0,      31]),
#  array([2671268,       0,       8]),
#  array([2681339,       0,       1]),
#  array([2688848,       0,      11]),
#  array([2698892,       0,       8]),
#  array([2708964,       0,       6]),
#  array([2716471,       0,      61]),
#  array([2726515,       0,       8]),
#  array([2736596,       0,       6]),
#  array([2744104,       0,      61]),
#  array([2754151,       0,       8]),
#  array([2764224,       0,       2]),
#  array([2771731,       0,      21]),
#  array([2781773,       0,       8]),
#  array([2791849,       0,       6]),
#  array([2799359,       0,      61]),
#  array([2809407,       0,       8]),
#  array([2819480,       0,       2]),
#  array([2826987,       0,      21]),
#  array([2837035,       0,       8]),
#  array([2847123,       0,       3]),
#  array([2854630,       0,      31]),
#  array([2864673,       0,       8]),
#  array([2874748,       0,       4]),
#  array([2882255,       0,      41]),
#  array([2892297,       0,       8]),
#  array([2902368,       0,       5]),
#  array([2909877,       0,      51]),
#  array([2919920,       0,       8]),
#  array([2929996,       0,       4]),
#  array([2937506,       0,      41]),
#  array([2947547,       0,       8]),
#  array([2957624,       0,       5]),
#  array([2965134,       0,      51]),
#  array([2975180,       0,       8]),
#  array([2985250,       0,       2]),
#  array([2992757,       0,      21]),
#  array([3002801,       0,       8]),
#  array([3012876,       0,       4]),
#  array([3020386,       0,      41]),
#  array([3030429,       0,       8]),
#  array([3040502,       0,       4]),
#  array([3048009,       0,      41]),
#  array([3058050,       0,       8]),
#  array([3068130,       0,       3]),
#  array([3075637,       0,      31]),
#  array([3085678,       0,       8]),
#  array([3095752,       0,       2]),
#  array([3103259,       0,      21]),
#  array([3113301,       0,       8]),
#  array([3123374,       0,       3]),
#  array([3130882,       0,      31]),
#  array([3140925,       0,       8]),
#  array([3151000,       0,       6]),
#  array([3158507,       0,      61]),
#  array([3168548,       0,       8]),
#  array([3178625,       0,       6]),
#  array([3186132,       0,      61]),
#  array([3196177,       0,       8]),
#  array([3206250,       0,       6]),
#  array([3213757,       0,      61]),
#  array([3223798,       0,       8]),
#  array([3233871,       0,       6]),
#  array([3241379,       0,      61]),
#  array([3251421,       0,       8]),
#  array([3261493,       0,       5]),
#  array([3269002,       0,      51]),
#  array([3279042,       0,       8]),
#  array([3289124,       0,       3]),
#  array([3296631,       0,      31]),
#  array([3306675,       0,       8]),
#  array([3316747,       0,       4]),
#  array([3324254,       0,      41]),
#  array([3334297,       0,       8]),
#  array([3344368,       0,       2]),
#  array([3351876,       0,      21]),
#  array([3361919,       0,       8]),
#  array([3371991,       0,       3]),
#  array([3379500,       0,      31]),
#  array([3389542,       0,       8]),
#  array([3399623,       0,       4]),
#  array([3407133,       0,      41]),
#  array([3417182,       0,       8]),
#  array([3427254,       0,       4]),
#  array([3434761,       0,      41]),
#  array([3444810,       0,       8]),
#  array([3454881,       0,       3]),
#  array([3462389,       0,      31]),
#  array([3472436,       0,       8]),
#  array([3482518,       0,       3]),
#  array([3490028,       0,      31]),
#  array([3500071,       0,       8]),
#  array([3510151,       0,       1]),
#  array([3517658,       0,      11]),
#  array([3527699,       0,       8]),
#  array([3537777,       0,       5]),
#  array([3545284,       0,      51]),
#  array([3555327,       0,       8]),
#  array([3565400,       0,       5]),
#  array([3572907,       0,      51]),
#  array([3582948,       0,       8]),
#  array([3593021,       0,       5]),
#  array([3600528,       0,      51]),
#  array([3610574,       0,       8]),
#  array([3620653,       0,       5]),
#  array([3628163,       0,      51]),
#  array([3638206,       0,       8]),
#  array([3648275,       0,       6]),
#  array([3655785,       0,      61]),
#  array([3665826,       0,       8]),
#  array([3675897,       0,       4]),
#  array([3683404,       0,      41]),
#  array([3693446,       0,       8]),
#  array([3703523,       0,       2]),
#  array([3711033,       0,      21]),
#  array([3721076,       0,       8]),
#  array([3731156,       0,       5]),
#  array([3738666,       0,      51]),
#  array([3748714,       0,       8]),
#  array([3758788,       0,       3]),
#  array([3766298,       0,      31]),
#  array([3776345,       0,       8]),
#  array([3786426,       0,       2]),
#  array([3793936,       0,      21]),
#  array([3803977,       0,       8]),
#  array([3814050,       0,       6]),
#  array([3821559,       0,      61]),
#  array([3831601,       0,       8]),
#  array([3841686,       0,       6]),
#  array([3849193,       0,      61]),
#  array([3859236,       0,       8]),
#  array([3869308,       0,       5]),
#  array([3876815,       0,      51]),
#  array([3886858,       0,       8]),
#  array([3896928,       0,       5]),
#  array([3904438,       0,      51]),
#  array([3914481,       0,       8]),
#  array([3924558,       0,       3]),
#  array([3932065,       0,      31]),
#  array([3942107,       0,       8]),
#  array([3952185,       0,       2]),
#  array([3959692,       0,      21]),
#  array([3969734,       0,       8]),
#  array([3979809,       0,       3]),
#  array([3987316,       0,      31]),
#  array([3997357,       0,       8]),
#  array([4007428,       0,       6]),
#  array([4014935,       0,      61]),
#  array([4024977,       0,       8]),
#  array([4035049,       0,       4]),
#  array([4042559,       0,      41]),
#  array([4052601,       0,       8]),
#  array([4062679,       0,       3]),
#  array([4070186,       0,      31]),
#  array([4080229,       0,       8]),
#  array([4090307,       0,       2]),
#  array([4097817,       0,      21]),
#  array([4107859,       0,       8]),
#  array([4117931,       0,       3]),
#  array([4125438,       0,      31]),
#  array([4135480,       0,       8]),
#  array([4145552,       0,       1]),
#  array([4153062,       0,      11]),
#  array([4163107,       0,       8]),
#  array([4173186,       0,       1]),
#  array([4180696,       0,      11]),
#  array([4190743,       0,       8]),
#  array([5865572,       0,       5]),
#  array([5873079,       0,      51]),
#  array([5883121,       0,       8]),
#  array([5893199,       0,       4]),
#  array([5900707,       0,      41]),
#  array([5910747,       0,       8]),
#  array([5920828,       0,       6]),
#  array([5928335,       0,      61]),
#  array([5938376,       0,       8]),
#  array([5948456,       0,       1]),
#  array([5955963,       0,      11]),
#  array([5966004,       0,       8]),
#  array([5976078,       0,       2]),
#  array([5983588,       0,      21]),
#  array([5993629,       0,       8]),
#  array([6003701,       0,       1]),
#  array([6011208,       0,      11]),
#  array([6021253,       0,       8]),
#  array([6031333,       0,       2]),
#  array([6038843,       0,      21]),
#  array([6048884,       0,       8]),
#  array([6058957,       0,       4]),
#  array([6066464,       0,      41]),
#  array([6076505,       0,       8]),
#  array([6086578,       0,       2]),
#  array([6094088,       0,      21]),
#  array([6104131,       0,       8]),
#  array([6114203,       0,       3]),
#  array([6121710,       0,      31]),
#  array([6131750,       0,       8]),
#  array([6141829,       0,       4]),
#  array([6149336,       0,      41]),
#  array([6159376,       0,       8]),
#  array([6169453,       0,       1]),
#  array([6176960,       0,      11]),
#  array([6187000,       0,       8]),
#  array([6197078,       0,       5]),
#  array([6204585,       0,      51]),
#  array([6214626,       0,       8]),
#  array([6224700,       0,       6]),
#  array([6232210,       0,      61]),
#  array([6242251,       0,       8]),
#  array([6252328,       0,       4]),
#  array([6259835,       0,      41]),
#  array([6269876,       0,       8]),
#  array([6279948,       0,       2]),
#  array([6287456,       0,      21]),
#  array([6297496,       0,       8]),
#  array([6307569,       0,       2]),
#  array([6315078,       0,      21]),
#  array([6325119,       0,       8]),
#  array([6335193,       0,       3]),
#  array([6342700,       0,      31]),
#  array([6352745,       0,       8]),
#  array([6362823,       0,       4]),
#  array([6370330,       0,      41]),
#  array([6380371,       0,       8]),
#  array([6390442,       0,       5]),
#  array([6397949,       0,      51]),
#  array([6407990,       0,       8]),
#  array([6418069,       0,       1]),
#  array([6425578,       0,      11]),
#  array([6435619,       0,       8]),
#  array([6445692,       0,       6]),
#  array([6453199,       0,      61]),
#  array([6463239,       0,       8]),
#  array([6473314,       0,       4]),
#  array([6480823,       0,      41]),
#  array([6490862,       0,       8]),
#  array([6500933,       0,       6]),
#  array([6508442,       0,      61]),
#  array([6518483,       0,       8]),
#  array([6528561,       0,       3]),
#  array([6536070,       0,      31]),
#  array([6546109,       0,       8]),
#  array([6556177,       0,       1]),
#  array([6563687,       0,      11]),
#  array([6573730,       0,       8]),
#  array([6583804,       0,       3]),
#  array([6591312,       0,      31]),
#  array([6601349,       0,       8]),
#  array([6611421,       0,       2]),
#  array([6618927,       0,      21]),
#  array([6628972,       0,       8]),
#  array([6639048,       0,       2]),
#  array([6646555,       0,      21]),
#  array([6656597,       0,       8]),
#  array([6666674,       0,       1]),
#  array([6674184,       0,      11]),
#  array([6684225,       0,       8]),
#  array([6694305,       0,       1]),
#  array([6701812,       0,      11]),
#  array([6711853,       0,       8]),
#  array([6721927,       0,       1]),
#  array([6729434,       0,      11]),
#  array([6739475,       0,       8]),
#  array([6749558,       0,       1]),
#  array([6757068,       0,      11]),
#  array([6767109,       0,       8]),
#  array([6777181,       0,       5]),
#  array([6784692,       0,      51]),
#  array([6794731,       0,       8]),
#  array([6804807,       0,       1]),
#  array([6812316,       0,      11]),
#  array([6822357,       0,       8]),
#  array([6832425,       0,       3]),
#  array([6839932,       0,      31]),
#  array([6849972,       0,       8]),
#  array([6860054,       0,       5]),
#  array([6867561,       0,      51]),
#  array([6877602,       0,       8]),
#  array([6887678,       0,       4]),
#  array([6895185,       0,      41]),
#  array([6905226,       0,       8]),
#  array([6915301,       0,       5]),
#  array([6922811,       0,      51]),
#  array([6932851,       0,       8]),
#  array([6942922,       0,       4]),
#  array([6950429,       0,      41]),
#  array([6960470,       0,       8]),
#  array([6970547,       0,       6]),
#  array([6978058,       0,      61]),
#  array([6988099,       0,       8]),
#  array([6998174,       0,       1]),
#  array([7005685,       0,      11]),
#  array([7015725,       0,       8]),
#  array([7025801,       0,       1]),
#  array([7033312,       0,      11]),
#  array([7043352,       0,       8]),
#  array([7053420,       0,       2]),
#  array([7060928,       0,      21]),
#  array([7070973,       0,       8]),
#  array([7081043,       0,       6]),
#  array([7088550,       0,      61]),
#  array([7098590,       0,       8]),
#  array([7108666,       0,       1]),
#  array([7116173,       0,      11]),
#  array([7126214,       0,       8]),
#  array([7136296,       0,       1]),
#  array([7143806,       0,      11]),
#  array([7153846,       0,       8]),
#  array([7163922,       0,       4]),
#  array([7171429,       0,      41]),
#  array([7181469,       0,       8]),
#  array([7191545,       0,       6]),
#  array([7199052,       0,      61]),
#  array([7209092,       0,       8]),
#  array([7219171,       0,       2]),
#  array([7226680,       0,      21]),
#  array([7236719,       0,       8]),
#  array([7246793,       0,       2]),
#  array([7254301,       0,      21]),
#  array([7264339,       0,       8]),
#  array([7274406,       0,       5]),
#  array([7281915,       0,      51]),
#  array([7291955,       0,       8]),
#  array([7302021,       0,       5]),
#  array([7309530,       0,      51]),
#  array([7319573,       0,       8]),
#  array([7329642,       0,       2]),
#  array([7337151,       0,      21]),
#  array([7347189,       0,       8]),
#  array([7357265,       0,       5]),
#  array([7364774,       0,      51]),
#  array([7374821,       0,       8]),
#  array([7384890,       0,       5]),
#  array([7392397,       0,      51]),
#  array([7402438,       0,       8]),
#  array([7412512,       0,       6]),
#  array([7420022,       0,      61]),
#  array([7430075,       0,       8]),
#  array([7440141,       0,       1]),
#  array([7447650,       0,      11]),
#  array([7457691,       0,       8]),
#  array([7467766,       0,       3]),
#  array([7475273,       0,      31]),
#  array([7485317,       0,       8]),
#  array([7495387,       0,       1]),
#  array([7502898,       0,      11]),
#  array([7512949,       0,       8]),
#  array([7523019,       0,       4]),
#  array([7530529,       0,      41]),
#  array([7540575,       0,       8]),
#  array([7550648,       0,       6]),
#  array([7558158,       0,      61]),
#  array([7568199,       0,       8]),
#  array([7578283,       0,       3]),
#  array([7585793,       0,      31]),
#  array([7595833,       0,       8]),
#  array([7605905,       0,       5]),
#  array([7613413,       0,      51]),
#  array([7623454,       0,       8]),
#  array([7633529,       0,       5]),
#  array([7641038,       0,      51]),
#  array([7651077,       0,       8]),
#  array([7661158,       0,       4]),
#  array([7668666,       0,      41]),
#  array([7678707,       0,       8]),
#  array([7688787,       0,       5]),
#  array([7696298,       0,      51]),
#  array([7706338,       0,       8]),
#  array([7716407,       0,       2]),
#  array([7723917,       0,      21]),
#  array([7733957,       0,       8]),
#  array([7744033,       0,       6]),
#  array([7751544,       0,      61]),
#  array([7761584,       0,       8]),
#  array([7771658,       0,       1]),
#  array([7779165,       0,      11]),
#  array([7789205,       0,       8]),
#  array([7799281,       0,       6]),
#  array([7806791,       0,      61]),
#  array([7816831,       0,       8]),
#  array([7826901,       0,       6]),
#  array([7834408,       0,      61]),
#  array([7844448,       0,       8]),
#  array([7854525,       0,       3]),
#  array([7862032,       0,      31]),
#  array([7872072,       0,       8]),
#  array([7882150,       0,       4]),
#  array([7889658,       0,      41]),
#  array([7899698,       0,       8]),
#  array([7909772,       0,       5]),
#  array([7917282,       0,      51]),
#  array([7927326,       0,       8]),
#  array([7937399,       0,       6]),
#  array([7944906,       0,      61]),
#  array([7954947,       0,       8]),
#  array([7965019,       0,       2]),
#  array([7972526,       0,      21]),
#  array([7982566,       0,       8]),
#  array([7992638,       0,       4]),
#  array([8000145,       0,      41]),
#  array([8010185,       0,       8]),
#  array([8020264,       0,       1]),
#  array([8027774,       0,      11]),
#  array([8037814,       0,       8]),
#  array([8047888,       0,       4]),
#  array([8055399,       0,      41]),
#  array([8065441,       0,       8]),
#  array([8075517,       0,       5]),
#  array([8083024,       0,      51]),
#  array([8093065,       0,       8]),
#  array([8103137,       0,       3]),
#  array([8110644,       0,      31]),
#  array([8120684,       0,       8]),
#  array([8130757,       0,       2]),
#  array([8138267,       0,      21]),
#  array([8148311,       0,       8]),
#  array([8158379,       0,       1]),
#  array([8165890,       0,      11]),
#  array([8175930,       0,       8]),
#  array([8186001,       0,       5]),
#  array([8193508,       0,      51]),
#  array([8203554,       0,       8]),
#  array([8213624,       0,       4]),
#  array([8221131,       0,      41]),
#  array([8231179,       0,       8]),
#  array([8241258,       0,       3]),
#  array([8248765,       0,      31]),
#  array([8258806,       0,       8]),
#  array([8268874,       0,       4]),
#  array([8276381,       0,      41]),
#  array([8286427,       0,       8]),
#  array([8296496,       0,       5]),
#  array([8304003,       0,      51]),
#  array([8314049,       0,       8]),
#  array([8324120,       0,       5]),
#  array([8331631,       0,      51]),
#  array([8341680,       0,       8]),
#  array([8351755,       0,       4]),
#  array([8359262,       0,      41]),
#  array([8369302,       0,       8]),
#  array([8379371,       0,       3]),
#  array([8386878,       0,      31]),
#  array([8396924,       0,       8]),
#  array([8406994,       0,       6]),
#  array([8414501,       0,      61]),
#  array([8424548,       0,       8]),
#  array([8434620,       0,       1]),
#  array([8442131,       0,      11]),
#  array([8452173,       0,       8]),
#  array([8462255,       0,       5]),
#  array([8469766,       0,      51]),
#  array([8479808,       0,       8]),
#  array([8489883,       0,       6]),
#  array([8497390,       0,      61]),
#  array([8507432,       0,       8]),
#  array([8517510,       0,       4]),
#  array([8525019,       0,      41]),
#  array([8535063,       0,       8]),
#  array([8545135,       0,       4]),
#  array([8552642,       0,      41]),
#  array([8562685,       0,       8]),
#  array([8572764,       0,       4]),
#  array([8580271,       0,      41]),
#  array([8590311,       0,       8]),
#  array([8600382,       0,       5]),
#  array([8607889,       0,      51]),
#  array([8617932,       0,       8]),
#  array([8628003,       0,       5]),
#  array([8635514,       0,      51]),
#  array([8645556,       0,       8]),
#  array([8655628,       0,       2]),
#  array([8663136,       0,      21]),
#  array([8673179,       0,       8]),
#  array([8683263,       0,       5]),
#  array([8690773,       0,      51]),
#  array([8700815,       0,       8]),
#  array([8710886,       0,       6]),
#  array([8718397,       0,      61]),
#  array([8728438,       0,       8]),
#  array([8738509,       0,       4]),
#  array([8746020,       0,      41]),
#  array([8756060,       0,       8]),
#  array([8766133,       0,       4]),
#  array([8773643,       0,      41]),
#  array([8783686,       0,       8]),
#  array([8793765,       0,       1]),
#  array([8801276,       0,      11]),
#  array([8811324,       0,       8]),
#  array([8821397,       0,       1]),
#  array([8828904,       0,      11]),
#  array([8838952,       0,       8]),
#  array([8849022,       0,       3]),
#  array([8856529,       0,      31]),
#  array([8866578,       0,       8]),
#  array([8876655,       0,       4]),
#  array([8884166,       0,      41]),
#  array([8894207,       0,       8]),
#  array([8904285,       0,       2]),
#  array([8911792,       0,      21]),
#  array([8921834,       0,       8]),
#  array([8931906,       0,       1]),
#  array([8939416,       0,      11]),
#  array([8949458,       0,       8]),
#  array([8959534,       0,       1]),
#  array([8967045,       0,      11]),
#  array([8977087,       0,       8]),
#  array([8987163,       0,       1]),
#  array([8994670,       0,      11]),
#  array([9004713,       0,       8]),
#  array([9014790,       0,       2]),
#  array([9022300,       0,      21]),
#  array([9032344,       0,       8]),
#  array([9042413,       0,       3]),
#  array([9049923,       0,      31]),
#  array([9059964,       0,       8]),
#  array([9070035,       0,       2]),
#  array([9077542,       0,      21]),
#  array([9087585,       0,       8]),
#  array([9097656,       0,       2]),
#  array([9105163,       0,      21]),
#  array([9115204,       0,       8]),
#  array([9125282,       0,       1]),
#  array([9132793,       0,      11]),
#  array([9142836,       0,       8]),
#  array([9152909,       0,       1]),
#  array([9160417,       0,      11]),
#  array([9170459,       0,       8]),
#  array([9180532,       0,       5]),
#  array([9188039,       0,      51]),
#  array([9198081,       0,       8]),
#  array([9208156,       0,       2]),
#  array([9215667,       0,      21]),
#  array([9225709,       0,       8]),
#  array([9235787,       0,       1]),
#  array([9243294,       0,      11]),
#  array([9253338,       0,       8]),
#  array([9263409,       0,       4]),
#  array([9270916,       0,      41]),
#  array([9280957,       0,       8]),
#  array([9291029,       0,       1]),
#  array([9298536,       0,      11]),
#  array([9308578,       0,       8]),
#  array([9318651,       0,       6]),
#  array([9326163,       0,      61]),
#  array([9336204,       0,       8]),
#  array([9346284,       0,       3]),
#  array([9353795,       0,      31]),
#  array([9363836,       0,       8]),
#  array([9373909,       0,       3]),
#  array([9381416,       0,      31]),
#  array([9391458,       0,       8]),
#  array([9401528,       0,       3]),
#  array([9409035,       0,      31]),
#  array([9419078,       0,       8]),
#  array([9429154,       0,       1]),
#  array([9436661,       0,      11]),
#  array([9446704,       0,       8]),
#  array([9456784,       0,       4]),
#  array([9464295,       0,      41]),
#  array([9474337,       0,       8]),
#  array([9484408,       0,       3]),
#  array([9491915,       0,      31]),
#  array([9501959,       0,       8]),
#  array([9512033,       0,       3]),
#  array([9519544,       0,      31]),
#  array([9529583,       0,       8]),
#  array([9539655,       0,       6]),
#  array([9547162,       0,      61]),
#  array([9557203,       0,       8]),
#  array([9567281,       0,       1]),
#  array([9574788,       0,      11]),
#  array([9584830,       0,       8]),
#  array([9594905,       0,       1]),
#  array([9602413,       0,      11]),
#  array([9612455,       0,       8]),
#  array([9622525,       0,       2]),
#  array([9630036,       0,      21]),
#  array([9640078,       0,       8]),
#  array([9650153,       0,       6]),
#  array([9657660,       0,      61]),
#  array([9667702,       0,       8]),
#  array([9677779,       0,       2]),
#  array([9685290,       0,      21]),
#  array([9695333,       0,       8]),
#  array([9705403,       0,       2]),
#  array([9712910,       0,      21]),
#  array([9722956,       0,       8]),
#  array([9733026,       0,       4]),
#  array([9740533,       0,      41]),
#  array([9750575,       0,       8]),
#  array([9760646,       0,       2]),
#  array([9768154,       0,      21]),
#  array([9778195,       0,       8]),
#  array([9788272,       0,       5]),
#  array([9795779,       0,      51]),
#  array([9805820,       0,       8]),
#  array([9815893,       0,       5]),
#  array([9823400,       0,      51]),
#  array([9833441,       0,       8]),
#  array([9843513,       0,       1]),
#  array([9851020,       0,      11]),
#  array([9861063,       0,       8]),
#  array([9871135,       0,       2]),
#  array([9878646,       0,      21]),
#  array([9888687,       0,       8]),
#  array([9898771,       0,       3]),
#  array([9906282,       0,      31]),
#  array([9916324,       0,       8]),
#  array([9926392,       0,       1]),
#  array([9933899,       0,      11]),
#  array([9943941,       0,       8]),
#  array([9954011,       0,       1]),
#  array([9961519,       0,      11]),
#  array([9971560,       0,       8]),
#  array([9981632,       0,       4]),
#  array([9989143,       0,      41]),
#  array([9999185,       0,       8]),
#  array([10009261,        0,        3]),
#  array([10016772,        0,       31]),
#  array([10026815,        0,        8]),
#  array([10031822,        0,       14])]

# %%
event_ids = {'Stimulus/S 11': 11,'Stimulus/S 21': 21,'Stimulus/S 31': 31,'Stimulus/S 41': 41,'Stimulus/S 51': 51,'Stimulus/S 61': 61, 'Stimulus/S 8': 8}
epochs = mne.Epochs(raw, events=events[0], event_id=event_ids, tmin=0, tmax=4, preload=True,baseline=(0, 0))
epochs
# Out:
# Not setting metadata
# 600 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 600 events and 10001 original time points ...
# 0 bad epochs dropped
# <Epochs |  600 events (all good), 0 - 4 sec, baseline 0 – 0 sec, ~1.61 GB, data loaded,
#  'Stimulus/S 11': 50
#  'Stimulus/S 21': 50
#  'Stimulus/S 31': 50
#  'Stimulus/S 41': 50
#  'Stimulus/S 51': 50
#  'Stimulus/S 61': 50
#  'Stimulus/S 8': 300>

# %%
epochs.get_data().shape
# Out:
# (600, 36, 10001)

# %%
mne.viz.plot_events(epochs.events[:100]);

# %% [markdown]
# ### Epochs Downsampling

# %%
epochs.resample(sfreq=1250)
epochs.get_data().shape
# Out:
# (600, 36, 5000)

# %%
# epochs.plot(n_epochs=5);

# %% [markdown]
# ### Repairing artifacts with ICA
# Note : ICA fitting is not deterministic (e.g., the components may get a sign flip on different runs, or may not always be returned in the same order), so we’ll also specify a random seed so that we get identical results each time this tutorial is built by our web servers

# %%
# ica = mne.preprocessing.ICA(n_components=20, max_iter='auto',random_state=0,method='infomax')
# ica.fit(epochs.copy())

# %%
# ica.plot_components();

# %%
# # use automatic detection
# bad_indx,scores = ica.find_bads_eog(raw,ch_name=["hEOG_L","hEOG_R","vEOG_U","vEOG_D"],threshold=2)
# print(bad_indx)

# %%
# epochs.plot(n_epochs=5);

# %%
# ica.exclude = bad_indx
# ica.apply(epochs.copy(),exclude=ica.exclude).plot(n_epochs=5);

# %%
# ica.apply(epochs,exclude=ica.exclude)

# %% [markdown]
# ### Repairing artifacts with regression
# Remove EOG artifact signals from other channels by regression.

# %%
# # plotting before
# # plot the evoked for the EEG and the EOG sensors
# fig = epochs.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# # Perform regression using the EOG sensor as independent variable and the EEG
# # sensors as dependent variables.
# model_plain = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(epochs)
# fig = model_plain.plot(vlim=(None, 0.4))  # regression coefficients as topomap
# fig.set_size_inches(3, 2);

# %%
# epochs_clean_plain = model_plain.apply(epochs)
# # After regression, we should redo the baseline correction
# epochs_clean_plain.apply_baseline(baseline=(3, 7))
# # Show the evoked potential computed on the corrected data
# fig = epochs_clean_plain.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# # create epochs with the evoked subtracted out
# epochs_sub = epochs.copy().subtract_evoked()

# # perform regression
# model_sub = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(epochs_sub)
# fig = model_sub.plot(vlim=(None, 0.4))
# fig.set_size_inches(3, 2)

# # apply the regression coefficients to the original epochs
# epochs_clean_sub = model_plain.apply(epochs).apply_baseline(baseline=(3, 7))
# fig = epochs_clean_sub.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# eog_epochs = mne.preprocessing.create_eog_epochs(raw)
# # We need to explicitly specify that we want to average the EOG channel too.
# eog_evoked = eog_epochs.average('all')
# eog_evoked.plot('all')
# fig.set_size_inches(6, 6)

# # perform regression on the evoked blink response
# model_evoked = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(eog_evoked)
# fig = model_evoked.plot(vlim=(None, 0.4))
# fig.set_size_inches(3, 2)

# # apply the regression coefficients to the original epochs
# epochs_clean_evoked = model_evoked.apply(epochs).apply_baseline(baseline=(3, 7))
# fig = epochs_clean_evoked.average('all').plot()
# fig.set_size_inches(6, 6)

# # for good measure, also show the effect on the blink evoked
# eog_evoked_clean = model_evoked.apply(eog_evoked)
# eog_evoked_clean.apply_baseline(baseline=(0, 0))
# eog_evoked_clean.plot('all')
# fig.set_size_inches(6, 6)

# %%
# order = np.concatenate([  # plotting order: EOG first, then EEG
#     mne.pick_types(raw.info, meg=False, eog=True),
#     mne.pick_types(raw.info, meg=False, eeg=True),
# ])
# raw_kwargs = dict(events=eog_epochs.events, order=order, start=13, duration=3,
#                   n_channels=10, scalings=dict(eeg=50e-6, eog=250e-6))

# # plot original data
# raw.plot(**raw_kwargs);

# # regress (using coefficients computed previously) and plot
# raw_clean = model_evoked.apply(raw)
# raw_clean.plot(**raw_kwargs);

# %%
# epochs.apply_baseline((None,0))

# %%
# epochs["Stimulus/S 41"].plot_image(picks=[5]); # picks=[channel index]

# %%
# epochs.equalize_event_counts(event_ids)
# epochs

# %% [markdown]
# ### Prepare & Split data

# %%
epochs.pick_types(eeg=True)
data = epochs.get_data()

# %%
labels = np.empty(shape=(data.shape[0]))
decode = {11: 0, 21: 1, 31: 2, 41:3, 51: 4, 61: 5, 8 :6}
k=0
for i in epochs.events:
    labels[k]=decode[i[2]]
    k+=1

# %%
data.shape
# Out:
# (600, 32, 5000)

# %%
labels.shape
# Out:
# (600,)

# %%
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size = 0.2,stratify=labels,shuffle=True)

# %%
y_train=tf.keras.utils.to_categorical(y_train,num_classes=7) 
y_val=tf.keras.utils.to_categorical(y_val,num_classes=7)

# %%
# Normaliation
# X_train = MinMaxScaler().fit_transform(X_train)
# X_val = MinMaxScaler().fit_transform(X_val)
X_train = (X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train))
X_val = (X_val-np.min(X_val))/(np.max(X_val)-np.min(X_val))

# %%
def preprocess_input(eeg_signals):
    eeg_signals_3d = np.zeros((eeg_signals.shape[0], 32, 5000, 3))
    for i in range(eeg_signals.shape[0]):
        trial_3d = np.dstack([eeg_signals[0],eeg_signals[0],eeg_signals[0]])
        eeg_signals_3d[i] = trial_3d
    return eeg_signals_3d
X_train = preprocess_input(X_train)
X_val = preprocess_input(X_val)

# %%
print('X_train: ',X_train.shape)
print('X_val:   ',X_val.shape)
print('y_train: ',y_train.shape)
print('y_val:   ',y_val.shape)
# Out:
# X_train:  (480, 32, 5000, 3)
# X_val:    (120, 32, 5000, 3)
# y_train:  (480, 7)
# y_val:    (120, 7)

# %% [markdown]
# ## Model EEGNet

# %%
from EEGModels import EEGNet 
model = EEGNet(nb_classes=7, Chans = 32, Samples = 5000, dropoutRate = 0.2, kernLength = 64, F1 = 8, D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

# %%
model.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.BinaryFocalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 5000, 1)]     0
#
#  conv2d (Conv2D)             (None, 32, 5000, 8)       512
#
#  batch_normalization (BatchN  (None, 32, 5000, 8)      32
#  ormalization)
#
#  depthwise_conv2d (Depthwise  (None, 1, 5000, 16)      512
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 1, 5000, 16)      64
#  hNormalization)
#
#  activation (Activation)     (None, 1, 5000, 16)       0
#
#  average_pooling2d (AverageP  (None, 1, 1250, 16)      0
#  ooling2D)
#
#  dropout (Dropout)           (None, 1, 1250, 16)       0
#
#  separable_conv2d (Separable  (None, 1, 1250, 16)      512
#  Conv2D)
#
#  batch_normalization_2 (Batc  (None, 1, 1250, 16)      64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1, 1250, 16)       0
#
#  average_pooling2d_1 (Averag  (None, 1, 156, 16)       0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 156, 16)        0
#
#  flatten (Flatten)           (None, 2496)              0
#
#  dense (Dense)               (None, 7)                 17479
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 19,175
# Trainable params: 19,095
# Non-trainable params: 80
# _________________________________________________________________

# %%
Epochs=40
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                     batch_size=32,
                     verbose=1)         #,callbacks=[early_stopping]
# Out:
# Epoch 1/40
# 15/15 [==============================] - 83s 5s/step - loss: 0.1656 - accuracy: 0.3104 - val_loss: 0.1883 - val_accuracy: 0.5000
# Epoch 2/40
# 15/15 [==============================] - 77s 5s/step - loss: 0.1126 - accuracy: 0.5000 - val_loss: 0.1801 - val_accuracy: 0.5000
# Epoch 3/40
# 15/15 [==============================] - 80s 5s/step - loss: 0.1051 - accuracy: 0.5000 - val_loss: 0.1764 - val_accuracy: 0.5000
# Epoch 4/40
# 15/15 [==============================] - 66s 4s/step - loss: 0.1040 - accuracy: 0.5000 - val_loss: 0.1754 - val_accuracy: 0.5000
# Epoch 5/40
# 15/15 [==============================] - 81s 5s/step - loss: 0.1029 - accuracy: 0.5000 - val_loss: 0.1755 - val_accuracy: 0.5000
# Epoch 6/40
# 15/15 [==============================] - 51s 3s/step - loss: 0.1021 - accuracy: 0.5000 - val_loss: 0.1740 - val_accuracy: 0.5000
# Epoch 7/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.1010 - accuracy: 0.5000 - val_loss: 0.1734 - val_accuracy: 0.5000
# Epoch 8/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.1000 - accuracy: 0.5000 - val_loss: 0.1725 - val_accuracy: 0.5000
# Epoch 9/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0993 - accuracy: 0.5021 - val_loss: 0.1709 - val_accuracy: 0.5000
# Epoch 10/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0985 - accuracy: 0.5021 - val_loss: 0.1711 - val_accuracy: 0.5000
# Epoch 11/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0974 - accuracy: 0.5021 - val_loss: 0.1689 - val_accuracy: 0.5000
# Epoch 12/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0967 - accuracy: 0.5042 - val_loss: 0.1677 - val_accuracy: 0.5000
# Epoch 13/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0962 - accuracy: 0.5042 - val_loss: 0.1669 - val_accuracy: 0.3167
# Epoch 14/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0960 - accuracy: 0.5042 - val_loss: 0.1638 - val_accuracy: 0.5000
# Epoch 15/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0954 - accuracy: 0.5063 - val_loss: 0.1631 - val_accuracy: 0.5000
# Epoch 16/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0946 - accuracy: 0.5083 - val_loss: 0.1606 - val_accuracy: 0.5000
# Epoch 17/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0945 - accuracy: 0.5063 - val_loss: 0.1607 - val_accuracy: 0.2583
# Epoch 18/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0939 - accuracy: 0.5250 - val_loss: 0.1607 - val_accuracy: 0.3917
# Epoch 19/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0936 - accuracy: 0.5125 - val_loss: 0.1574 - val_accuracy: 0.3417
# Epoch 20/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0927 - accuracy: 0.5188 - val_loss: 0.1551 - val_accuracy: 0.4833
# Epoch 21/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0926 - accuracy: 0.5229 - val_loss: 0.1561 - val_accuracy: 0.4333
# Epoch 22/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0921 - accuracy: 0.5250 - val_loss: 0.1535 - val_accuracy: 0.4333
# Epoch 23/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0919 - accuracy: 0.5271 - val_loss: 0.1522 - val_accuracy: 0.2167
# Epoch 24/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0914 - accuracy: 0.5417 - val_loss: 0.1497 - val_accuracy: 0.4917
# Epoch 25/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0911 - accuracy: 0.5229 - val_loss: 0.1496 - val_accuracy: 0.1167
# Epoch 26/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0909 - accuracy: 0.5521 - val_loss: 0.1472 - val_accuracy: 0.2750
# Epoch 27/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0906 - accuracy: 0.5292 - val_loss: 0.1470 - val_accuracy: 0.4083
# Epoch 28/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0906 - accuracy: 0.5375 - val_loss: 0.1400 - val_accuracy: 0.2667
# Epoch 29/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0901 - accuracy: 0.5396 - val_loss: 0.1387 - val_accuracy: 0.4917
# Epoch 30/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0898 - accuracy: 0.5396 - val_loss: 0.1339 - val_accuracy: 0.2667
# Epoch 31/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0898 - accuracy: 0.5500 - val_loss: 0.1300 - val_accuracy: 0.4917
# Epoch 32/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0890 - accuracy: 0.5458 - val_loss: 0.1318 - val_accuracy: 0.4917
# Epoch 33/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0893 - accuracy: 0.5437 - val_loss: 0.1313 - val_accuracy: 0.4167
# Epoch 34/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0889 - accuracy: 0.5667 - val_loss: 0.1225 - val_accuracy: 0.5000
# Epoch 35/40
# 15/15 [==============================] - 40s 3s/step - loss: 0.0888 - accuracy: 0.5562 - val_loss: 0.1162 - val_accuracy: 0.5000
# Epoch 36/40
# 15/15 [==============================] - 40s 3s/step - loss: 0.0881 - accuracy: 0.5688 - val_loss: 0.1182 - val_accuracy: 0.5000
# Epoch 37/40
# 15/15 [==============================] - 39s 3s/step - loss: 0.0879 - accuracy: 0.5562 - val_loss: 0.1160 - val_accuracy: 0.5000
# Epoch 38/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0883 - accuracy: 0.5521 - val_loss: 0.1144 - val_accuracy: 0.5000
# Epoch 39/40
# 15/15 [==============================] - 37s 2s/step - loss: 0.0880 - accuracy: 0.5771 - val_loss: 0.1177 - val_accuracy: 0.5000
# Epoch 40/40
# 15/15 [==============================] - 38s 3s/step - loss: 0.0877 - accuracy: 0.5813 - val_loss: 0.1115 - val_accuracy: 0.5000

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(X_train,y_train)
# Out:
# 15/15 [==============================] - 3s 198ms/step - loss: 0.1012 - accuracy: 0.5500
# [0.10122270882129669, 0.550000011920929]

# %%
model.evaluate(X_val,y_val)
# Out:
# 4/4 [==============================] - 1s 178ms/step - loss: 0.1115 - accuracy: 0.5000
# [0.11149044334888458, 0.5]

# %% [markdown]
# ## Model CSP + MLP

# %%
from mne.decoding import CSP

csp = CSP(n_components=32, reg=None, log=True, norm_trace=True)

# plot CSP patterns estimated on full data for visualization
csp.fit_transform(X_train, y_train)

# Apply CSP transform to training data
X_train_csp = csp.transform(X_train)
X_val_csp = csp.transform(X_val)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6 (2.2e-16 eps * 32 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 21 (2.2e-16 eps * 32 dim * 3e+15  max singular value)
#     Estimated rank (mag): 32
#     MAG: rank 32 computed from 32 data channels with 0 projectors
# Reducing data rank from 32 -> 32
# Estimating covariance using EMPIRICAL
# Done.

# %%
print(X_train_csp.shape)
print(X_val_csp.shape)
# Out:
# (480, 32)
# (120, 32)

# %%
# Import MLPClassifer 
from sklearn.neural_network import MLPClassifier

# Create model object
clf = MLPClassifier(hidden_layer_sizes=(10, 5),
                    random_state=10,
                    verbose=True,
                    max_iter=50,
                    learning_rate_init=0.1)

# Fit data onto the model
clf.fit(X_train_csp,y_train)
# Out:
# Iteration 1, loss = 2.37727654
# Iteration 2, loss = 1.76380225
# Iteration 3, loss = 1.65832954
# Iteration 4, loss = 1.60375443
# Iteration 5, loss = 1.59434772
# Iteration 6, loss = 1.60056497
# Iteration 7, loss = 1.60322042
# Iteration 8, loss = 1.60190120
# Iteration 9, loss = 1.59858002
# Iteration 10, loss = 1.59510630
# Iteration 11, loss = 1.59328746
# Iteration 12, loss = 1.59358916
# Iteration 13, loss = 1.59179084
# Iteration 14, loss = 1.59053209
# Iteration 15, loss = 1.59029161
# Iteration 16, loss = 1.59179487
# Iteration 17, loss = 1.59157994
# Iteration 18, loss = 1.59131856
# Iteration 19, loss = 1.59013391
# Iteration 20, loss = 1.58935666
# Iteration 21, loss = 1.59053537
# Iteration 22, loss = 1.59070619
# Iteration 23, loss = 1.59109387
# Iteration 24, loss = 1.59123014
# Iteration 25, loss = 1.59027794
# Iteration 26, loss = 1.59049928
# Iteration 27, loss = 1.59025918
# Iteration 28, loss = 1.59072443
# Iteration 29, loss = 1.58989031
# Iteration 30, loss = 1.59056622
# Iteration 31, loss = 1.59028211
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(10, 5), learning_rate_init=0.1, max_iter=50,
#               random_state=10, verbose=True)

# %%
# Make prediction on test dataset
ypred=clf.predict(X_val_csp)

# Import accuracy score 
from sklearn.metrics import accuracy_score

# Calcuate accuracy
accuracy_score(y_val,ypred)
# Out:
# 0.5

# %% [markdown]
# ## Model CNN

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(32,5000)),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(256, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
model2.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.BinaryFocalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 30, 64)            960064
#
#  max_pooling1d (MaxPooling1D  (None, 15, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 13, 128)           24704
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 128)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 4, 256)            98560
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1,349,575
# Trainable params: 1,349,575
# Non-trainable params: 0
# _________________________________________________________________

# %%
Epochs=100
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model2.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                     batch_size=32,
                     verbose=1)         #,callbacks=[early_stopping]
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 63ms/step - loss: 0.1663 - accuracy: 0.4729 - val_loss: 0.1202 - val_accuracy: 0.5000
# Epoch 2/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1113 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1066 - accuracy: 0.5000 - val_loss: 0.1069 - val_accuracy: 0.5000
# Epoch 4/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1062 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 5/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1058 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 7/100
# 15/15 [==============================] - 1s 61ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 8/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 9/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 10/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1072 - val_accuracy: 0.5000
# Epoch 11/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 12/100
# 15/15 [==============================] - 1s 59ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 13/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1067 - val_accuracy: 0.5000
# Epoch 14/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 15/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 16/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 17/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1067 - val_accuracy: 0.5000
# Epoch 18/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 19/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 20/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 21/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 22/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 23/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 24/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 25/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1058 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 26/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 27/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 28/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 29/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1068 - val_accuracy: 0.5000
# Epoch 30/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 31/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 32/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 33/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 34/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 35/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 36/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 37/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1069 - val_accuracy: 0.5000
# Epoch 38/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 39/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 40/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 41/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1068 - val_accuracy: 0.5000
# Epoch 42/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1059 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 43/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 44/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 45/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 46/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 47/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 48/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 49/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 50/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 51/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 52/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1052 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 53/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 54/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 55/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1065 - val_accuracy: 0.5000
# Epoch 56/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 57/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1068 - val_accuracy: 0.5000
# Epoch 58/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 59/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 60/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 61/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 62/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 63/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 64/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 65/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 66/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 67/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1058 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 68/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 69/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 70/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 71/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 72/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 73/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 74/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 75/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 76/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 77/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1063 - val_accuracy: 0.5000
# Epoch 78/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 79/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1069 - val_accuracy: 0.5000
# Epoch 80/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 81/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 82/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 83/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 84/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 85/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 86/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1057 - accuracy: 0.5000 - val_loss: 0.1057 - val_accuracy: 0.5000
# Epoch 87/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000
# Epoch 88/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 89/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1056 - accuracy: 0.5000 - val_loss: 0.1066 - val_accuracy: 0.5000
# Epoch 90/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 91/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 92/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1059 - val_accuracy: 0.5000
# Epoch 93/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 94/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.1052 - accuracy: 0.5000 - val_loss: 0.1061 - val_accuracy: 0.5000
# Epoch 95/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1055 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 96/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1054 - accuracy: 0.5000 - val_loss: 0.1065 - val_accuracy: 0.5000
# Epoch 97/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1058 - val_accuracy: 0.5000
# Epoch 98/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1062 - val_accuracy: 0.5000
# Epoch 99/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1060 - val_accuracy: 0.5000
# Epoch 100/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.1053 - accuracy: 0.5000 - val_loss: 0.1064 - val_accuracy: 0.5000

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model2.evaluate(X_train,y_train)
# Out:
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1052 - accuracy: 0.5000
# [0.10515839606523514, 0.5]

# %%
model2.evaluate(X_val,y_val)
# Out:
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1064 - accuracy: 0.5000
# [0.1063913106918335, 0.5]

# %% [markdown]
# ## Model ResNet

# %%
ResNet50 = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(32, 5000, 3),
)

# %%
model = tf.keras.models.Sequential([
    ResNet50,
    # tf.keras.layers.Flatten(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1024, activation='relu'),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(7,activation='softmax')
])

# %%
model.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.BinaryFocalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 157, 2048)      23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dense_3 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 25,693,063
# Trainable params: 25,639,943
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
Epochs=10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                    batch_size=32,
                    verbose=1)#,callbacks=[early_stopping]
# Out:
# Epoch 1/10
