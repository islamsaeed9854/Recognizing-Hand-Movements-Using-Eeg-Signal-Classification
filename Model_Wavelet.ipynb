# %% [markdown]
# ## Arm Reaching (MI Session 1)

# %%
import os
import glob
import numpy as np
import mne
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from google.colab import drive
# drive.mount('/content/drive')
from scipy.io import loadmat
from scipy.signal import butter, lfilter
warnings.filterwarnings('ignore')

# %% [markdown]
# ### BrainVision (.vhdr, .vmrk, .eeg)
#
# The BrainVision file format consists of three separate files:
#
# 1. A text header file (.vhdr) containing meta data.
#
# 2. A text marker file (.vmrk) containing information about events in the data.
#
# 3. A binary data file (.eeg) containing the voltage values of the EEG.

# %%
folder_path=r'D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI'
folder_files=os.listdir(folder_path)
for i in folder_files:
    print(i)
# Out:
# session1_sub10_reaching_MI.eeg
# session1_sub10_reaching_MI.vhdr
# session1_sub10_reaching_MI.vmrk
# session1_sub1_reaching_MI.eeg
# session1_sub1_reaching_MI.vhdr
# session1_sub1_reaching_MI.vmrk
# session1_sub2_reaching_MI.eeg
# session1_sub2_reaching_MI.vhdr
# session1_sub2_reaching_MI.vmrk
# session1_sub3_reaching_MI.eeg
# session1_sub3_reaching_MI.vhdr
# session1_sub3_reaching_MI.vmrk
# session1_sub4_reaching_MI.eeg
# session1_sub4_reaching_MI.vhdr
# session1_sub4_reaching_MI.vmrk
# session1_sub5_reaching_MI.eeg
# session1_sub5_reaching_MI.vhdr
# session1_sub5_reaching_MI.vmrk
# session1_sub6_reaching_MI.eeg
# session1_sub6_reaching_MI.vhdr
# session1_sub6_reaching_MI.vmrk
# session1_sub7_reaching_MI.eeg
# session1_sub7_reaching_MI.vhdr
# session1_sub7_reaching_MI.vmrk
# session1_sub8_reaching_MI.eeg
# session1_sub8_reaching_MI.vhdr
# session1_sub8_reaching_MI.vmrk
# session1_sub9_reaching_MI.eeg
# session1_sub9_reaching_MI.vhdr
# session1_sub9_reaching_MI.vmrk

# %%
eeg,vhdr,vmrk = [],[],[]

for i in folder_files:
    file=folder_path+'\\'+i
    if '.eeg' in file:
        eeg.append(file) 
    elif '.vhdr' in file:
        vhdr.append(file) 
    else:
        vmrk.append(file)
        
for i in range(0,len(eeg)):
    print(eeg[i]+'\n'+vhdr[i]+'\n'+vmrk[i]+'\n')
# Out:
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub1_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub2_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub3_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub4_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub5_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub6_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub7_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub8_reaching_MI.vmrk
#
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.eeg
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.vhdr
# D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub9_reaching_MI.vmrk

# %% [markdown]
# ### Read Raw Signals

# %%
raw = mne.io.read_raw_brainvision(vhdr[0], misc='auto', scale=1.0, preload=True, verbose=None)
raw # OR raw.info
# Out:
# Extracting parameters from D:\EEG_RawData\EEG_RawData\Arm-Reaching\MI\session1_sub10_reaching_MI.vhdr...
# Setting channel info structure...
# Reading 0 ... 8487899  =      0.000 ...  3395.160 secs...
# <RawBrainVision | session1_sub10_reaching_MI.eeg, 71 x 8487900 (3395.2 s), ~4.49 GB, data loaded>

# %%
raw.set_channel_types(mapping={'hEOG_L': 'eog', 'hEOG_R': 'eog', 'vEOG_U': 'eog', 'vEOG_D': 'eog'})
raw.set_channel_types(mapping={'EMG_1': 'emg', 'EMG_2': 'emg', 'EMG_3': 'emg', 'EMG_4': 'emg', 'EMG_5': 'emg', 'EMG_6': 'emg', 'EMG_ref': 'emg'})
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, AFz, F7, F5, F3, F1, Fz, FT7, FC5, FC3, FC1, T7, ...
#  chs: 60 EEG, 4 EOG, 7 EMG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 1000.0 Hz
#  meas_date: 2019-07-08 12:11:40 UTC
#  nchan: 71
#  projs: []
#  sfreq: 2500.0 Hz
# >

# %%
print('bad channels:', raw.info['bads'])  # chs marked "bad" during acquisition
print(raw.info['sfreq'], 'Hz')            # sampling frequency
print(raw.info['description'], '\n')      # miscellaneous acquisition info
# Out:
# bad channels: []
# 2500.0 Hz
# None

# %%
raw.plot(n_channels=71);
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ### For One Session, Each Subject Do :
#  - 50 Trials For Each Class : 50 x 6 ( Classes ) = Total 300 Trials
#
#  - Each Trial has Time Duration 7s ( 3s Visual Cue + 4s Movement Implementation )
#
#  - and There Are 300 Rest Periods Between Those Trials ( Each Rest Period has Time Duration 4s )
#
#  - Finally,
#       Total Session Time = 50 x 6 x 7 + 300 x 4 = almost 3300 seconds

# %%
print('First Time : ',raw.first_time)
print('Last Time  : ',raw._last_time)
# Out:
# First Time :  0.0
# Last Time  :  3395.1596

# %% [markdown]
# - Therefore, The Total Count of Samples For All Trials : 300 ( Trials ) x 7s x 2500 (Fs) + 300 (Rests) x 4s x 2500 (Fs) is almost 8,250,000

# %%
print('Total Samples : ',len(raw))
print('Start : ',raw._first_samps) 
print('End : ',raw._last_samps)
# Out:
# Total Samples :  8487900
# Start :  [0]
# End :  [8487899]

# %% [markdown]
# ### time_as_index()
# - Convert time to indices ( time ( s ) : index ( 0-based ) )
#
# - Input : List of numbers or a number representing points in time.
#
# - Return : Indices relative to first_samp corresponding to the times supplied.

# %%
print(raw.time_as_index([1, 2, 3, 4, 5]), '\n')
print(np.diff(raw.time_as_index([1, 2, 3])))
# Out:
# [ 2500  5000  7500 10000 12500]
#
# [2500 2500]

# %% [markdown]
# ### Electrodes Handling :
# ### pick_types() : Picking Some Type of Signals and Ignore Others.
# ### pick_channels() : pick channels by name.
# ### drop_channels() : method to remove channels by name.

# %%
# this piece of code does not make changes in this case, only for learn

# eeg_and_eog = raw.copy().pick_types(emg=False, eeg=True, eog=True)
# print(len(raw.ch_names), '→', len(eeg_and_eog.ch_names))

# %% [markdown]
# ### We Will Select Channels According to International Standard 10–20 system
#
# <img src="The-location-map-of-32-channels-cap-The-electrodes-can-be-divided-into-3-groups.png" style="width:400px;hight:400;"/>

# %%
print(raw.ch_names)
# Out:
# ['Fp1', 'AF7', 'AF3', 'AFz', 'F7', 'F5', 'F3', 'F1', 'Fz', 'FT7', 'FC5', 'FC3', 'FC1', 'T7', 'C5', 'C3', 'C1', 'Cz', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'P7', 'P5', 'P3', 'P1', 'Pz', 'PO7', 'PO3', 'POz', 'hEOG_L', 'hEOG_R', 'vEOG_U', 'vEOG_D', 'Fp2', 'AF4', 'AF8', 'F2', 'F4', 'F6', 'F8', 'FC2', 'FC4', 'FC6', 'FT8', 'C2', 'C4', 'C6', 'T8', 'CP2', 'CP4', 'CP6', 'TP8', 'P2', 'P4', 'P6', 'P8', 'PO4', 'PO8', 'O1', 'Oz', 'O2', 'Iz', 'EMG_1', 'EMG_2', 'EMG_3', 'EMG_4', 'EMG_5', 'EMG_6', 'EMG_ref']

# %%
selected_channels = ["Fp1", "AF3","F7","F3","FC1","FC5","T7","C3","CP1","CP5","P7","P3", "PO3", "O1",  # Brain Left Side
                     "Fz","Cz","Pz","Oz",                                                              # Brain Mid
                     "O2","FC2","F4","F8","AF4","Fp2","C4", "T8","FC6","CP2","PO4","P4","P8","CP6",    # Brain Right Side   
                     "hEOG_L", "hEOG_R", "vEOG_U", "vEOG_D"]                                           # EOG Channels

# %%
raw.pick_channels(ch_names=selected_channels)
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage)
print(len(raw.ch_names))
# Out:
# 36

# %%
raw.plot(n_channels=36);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.plot_sensors(show_names=True,sphere=0.11);
fig = montage.plot(kind='3d',show=False)
fig = fig.gca().view_init(azim=70, elev=15)  # set view angle for tutorial
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.

# %% [markdown]
# ### Plotting spectral density of continuous data
#
# - To visualize the frequency content of continuous data
#
# - the Raw object provides a compute_psd() method to compute spectral density and the resulting Spectrum object has a plot() method

# %%
spectrum = raw.compute_psd()
spectrum.plot(average=True)
# Out:
# Effective window size : 0.102 (s)
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ### plot spectral power estimates across sensors as a scalp topography
# - will compute power based on magnetometer channels (if present), and will plot the power estimates on a dB-like log-scale.

# %%
spectrum.plot_topomap(bands={'Alpha (8-12 Hz)': (8, 12), 'Beta (12-30 Hz)': (12, 30),'Gamma (30-45 Hz)': (30,45)});

# %% [markdown]
# ### plot the PSD for every sensor on its own axes
# - the axes arranged spatially to correspond to sensor locations in space.

# %%
spectrum.plot_topo();

# %% [markdown]
# ### Bandpass Filtering the Data
# - Filtering to remove slow drift.
# - Before we run the ICA, an important step is filtering the data to remove low-frequency drifts, which can negatively affect the quality of the ICA fit.

# %%
# raw.filter(l_freq=8,h_freq=30)

# %%
# raw.plot(n_channels=36);

# %%
# spectrum = raw.compute_psd()
# spectrum.plot(average=True)

# %% [markdown]
# ### Refrencing EEG

# %%
# # Average reference. This is normally added by default, but can also be added
# # explicitly.
# raw.set_eeg_reference(ref_channels='average')
# raw.plot();

# %%
# ### Detect Ocular artifacts (EOG)

# - MNE-Python includes functions for detecting and extracting ocular artifacts: find_eog_events() and create_eog_epochs(). Once again we’ll use the higher-level convenience function that automatically finds the artifacts and extracts them in to an Epochs object in one step. 

# - ocular artifacts are usually most prominent in the EEG channels.

# - note that there are many fewer blinks than heartbeats, which makes the image plots appear somewhat blocky.

# %%
# # baseline : The electrical signal from a sensor when no measured variable is present. Often referred to the output at no-load condition
# eog_epochs = mne.preprocessing.create_eog_epochs(raw,ch_name=["hEOG_L", "hEOG_R", "vEOG_U", "vEOG_D"], baseline=(-0.5, -0.2))
# eog_epochs.plot_image(combine='mean');
# eog_epochs.average().plot_joint();

# %%
# eog_epochs

# %%
# ### Repairing artifacts with regression --Raw Data--
# Remove EOG artifact signals from other channels by regression.

# %%
# weights = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(raw)

# %%
# fig = weights.plot(vlim=(None, 0.4))  # regression coefficients / weights as topomap
# fig.set_size_inches(3, 2)

# %%
# # Fit the regression model
# raw_clean = weights.apply(raw, copy=False)

# # Show the filter weights in a topomap
# weights.plot();

# %%
# ### Repairing artifacts with ICA
# Note : ICA fitting is not deterministic (e.g., the components may get a sign flip on different runs, or may not always be returned in the same order), so we’ll also specify a random seed so that we get identical results each time this tutorial is built by our web servers

# %%
# ica = mne.preprocessing.ICA(n_components=32, max_iter='auto',random_state=0,method='infomax')
# ica.fit(raw.copy())

# %%
# ica.plot_components();

# %%
# # use automatic detection
# bad_indx,scores = ica.find_bads_eog(raw,ch_name=["hEOG_L","hEOG_R","vEOG_U","vEOG_D"],threshold=3,)
# print(bad_indx)

# %%
# raw.plot(n_channels=32);

# %%
# ica.exclude = bad_indx
# ica.apply(raw.copy(),exclude=ica.exclude).plot();

# %%
# ica.apply(raw,exclude=ica.exclude)

# %% [markdown]
# ### Read Events & Epoching

# %%
events = mne.events_from_annotations(raw)
# Out:
# Used Annotations descriptions: ['Comment/actiCAP Data On', 'New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S  3', 'Stimulus/S  4', 'Stimulus/S  5', 'Stimulus/S  6', 'Stimulus/S  8', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 14', 'Stimulus/S 21', 'Stimulus/S 31', 'Stimulus/S 41', 'Stimulus/S 51', 'Stimulus/S 61']

# %%
list(events[0])
# Out:
# [array([    0,     0, 99999]),
#  array([    0,     0, 10001]),
#  array([38900,     0,    13]),
#  array([48973,     0,     4]),
#  array([56489,     0,    41]),
#  array([66533,     0,     8]),
#  array([76625,     0,     3]),
#  array([84137,     0,    31]),
#  array([94176,     0,     8]),
#  array([104251,      0,      1]),
#  array([111762,      0,     11]),
#  array([121801,      0,      8]),
#  array([131884,      0,      6]),
#  array([139394,      0,     61]),
#  array([149441,      0,      8]),
#  array([159529,      0,      2]),
#  array([167039,      0,     21]),
#  array([177079,      0,      8]),
#  array([187159,      0,      2]),
#  array([194669,      0,     21]),
#  array([204708,      0,      8]),
#  array([214780,      0,      3]),
#  array([222290,      0,     31]),
#  array([232331,      0,      8]),
#  array([242410,      0,      4]),
#  array([249920,      0,     41]),
#  array([259961,      0,      8]),
#  array([270034,      0,      1]),
#  array([277544,      0,     11]),
#  array([287588,      0,      8]),
#  array([297666,      0,      5]),
#  array([305176,      0,     51]),
#  array([315217,      0,      8]),
#  array([325294,      0,      1]),
#  array([332804,      0,     11]),
#  array([342848,      0,      8]),
#  array([352940,      0,      6]),
#  array([360450,      0,     61]),
#  array([370494,      0,      8]),
#  array([380569,      0,      1]),
#  array([388079,      0,     11]),
#  array([398118,      0,      8]),
#  array([408195,      0,      1]),
#  array([415706,      0,     11]),
#  array([425750,      0,      8]),
#  array([435823,      0,      5]),
#  array([443333,      0,     51]),
#  array([453373,      0,      8]),
#  array([463455,      0,      3]),
#  array([470965,      0,     31]),
#  array([481006,      0,      8]),
#  array([491079,      0,      3]),
#  array([498589,      0,     31]),
#  array([508630,      0,      8]),
#  array([518703,      0,      1]),
#  array([526211,      0,     11]),
#  array([536253,      0,      8]),
#  array([546326,      0,      1]),
#  array([553833,      0,     11]),
#  array([563885,      0,      8]),
#  array([573974,      0,      6]),
#  array([581484,      0,     61]),
#  array([591524,      0,      8]),
#  array([601615,      0,      3]),
#  array([609127,      0,     31]),
#  array([619170,      0,      8]),
#  array([629246,      0,      4]),
#  array([636755,      0,     41]),
#  array([646803,      0,      8]),
#  array([656877,      0,      5]),
#  array([664387,      0,     51]),
#  array([674430,      0,      8]),
#  array([684508,      0,      3]),
#  array([692015,      0,     31]),
#  array([702055,      0,      8]),
#  array([712129,      0,      1]),
#  array([719637,      0,     11]),
#  array([729679,      0,      8]),
#  array([739752,      0,      3]),
#  array([747258,      0,     31]),
#  array([757303,      0,      8]),
#  array([767379,      0,      5]),
#  array([774889,      0,     51]),
#  array([784930,      0,      8]),
#  array([795016,      0,      1]),
#  array([802525,      0,     11]),
#  array([812565,      0,      8]),
#  array([822640,      0,      2]),
#  array([830149,      0,     21]),
#  array([840190,      0,      8]),
#  array([850265,      0,      5]),
#  array([857776,      0,     51]),
#  array([867823,      0,      8]),
#  array([877899,      0,      6]),
#  array([885410,      0,     61]),
#  array([895449,      0,      8]),
#  array([905529,      0,      5]),
#  array([913036,      0,     51]),
#  array([923074,      0,      8]),
#  array([933145,      0,      4]),
#  array([940655,      0,     41]),
#  array([950701,      0,      8]),
#  array([960780,      0,      2]),
#  array([968290,      0,     21]),
#  array([978341,      0,      8]),
#  array([988422,      0,      2]),
#  array([995933,      0,     21]),
#  array([1005976,       0,       8]),
#  array([1016057,       0,       1]),
#  array([1023564,       0,      11]),
#  array([1033603,       0,       8]),
#  array([1043678,       0,       6]),
#  array([1051189,       0,      61]),
#  array([1061231,       0,       8]),
#  array([1071309,       0,       5]),
#  array([1078815,       0,      51]),
#  array([1088856,       0,       8]),
#  array([1098928,       0,       6]),
#  array([1106435,       0,      61]),
#  array([1116474,       0,       8]),
#  array([1126551,       0,       1]),
#  array([1134058,       0,      11]),
#  array([1144097,       0,       8]),
#  array([1154175,       0,       5]),
#  array([1161682,       0,      51]),
#  array([1171722,       0,       8]),
#  array([1181801,       0,       4]),
#  array([1189312,       0,      41]),
#  array([1199355,       0,       8]),
#  array([1209428,       0,       3]),
#  array([1216936,       0,      31]),
#  array([1226975,       0,       8]),
#  array([1237053,       0,       6]),
#  array([1244563,       0,      61]),
#  array([1254603,       0,       8]),
#  array([1264680,       0,       2]),
#  array([1272188,       0,      21]),
#  array([1282226,       0,       8]),
#  array([1292297,       0,       2]),
#  array([1299806,       0,      21]),
#  array([1309847,       0,       8]),
#  array([1319924,       0,       1]),
#  array([1327432,       0,      11]),
#  array([1337473,       0,       8]),
#  array([1347551,       0,       6]),
#  array([1355058,       0,      61]),
#  array([1365097,       0,       8]),
#  array([1375169,       0,       2]),
#  array([1382676,       0,      21]),
#  array([1392715,       0,       8]),
#  array([1402791,       0,       1]),
#  array([1410298,       0,      11]),
#  array([1420345,       0,       8]),
#  array([1430431,       0,       4]),
#  array([1437941,       0,      41]),
#  array([1447982,       0,       8]),
#  array([1458059,       0,       2]),
#  array([1465566,       0,      21]),
#  array([1475605,       0,       8]),
#  array([1485675,       0,       2]),
#  array([1493183,       0,      21]),
#  array([1503221,       0,       8]),
#  array([1513290,       0,       4]),
#  array([1520797,       0,      41]),
#  array([1530837,       0,       8]),
#  array([1540914,       0,       6]),
#  array([1548421,       0,      61]),
#  array([1558461,       0,       8]),
#  array([1568541,       0,       2]),
#  array([1576048,       0,      21]),
#  array([1586088,       0,       8]),
#  array([1596162,       0,       2]),
#  array([1603670,       0,      21]),
#  array([1613708,       0,       8]),
#  array([1623783,       0,       4]),
#  array([1631291,       0,      41]),
#  array([1641334,       0,       8]),
#  array([1651413,       0,       5]),
#  array([1658920,       0,      51]),
#  array([1668960,       0,       8]),
#  array([1679043,       0,       6]),
#  array([1686550,       0,      61]),
#  array([1696589,       0,       8]),
#  array([1706662,       0,       1]),
#  array([1714171,       0,      11]),
#  array([1724210,       0,       8]),
#  array([1734282,       0,       6]),
#  array([1741790,       0,      61]),
#  array([1751831,       0,       8]),
#  array([1761912,       0,       4]),
#  array([1769420,       0,      41]),
#  array([1779459,       0,       8]),
#  array([1789539,       0,       6]),
#  array([1797046,       0,      61]),
#  array([1807085,       0,       8]),
#  array([1817158,       0,       5]),
#  array([1824668,       0,      51]),
#  array([1834708,       0,       8]),
#  array([1844780,       0,       3]),
#  array([1852287,       0,      31]),
#  array([1862330,       0,       8]),
#  array([1872404,       0,       2]),
#  array([1879912,       0,      21]),
#  array([1889950,       0,       8]),
#  array([1900027,       0,       4]),
#  array([1907534,       0,      41]),
#  array([1917573,       0,       8]),
#  array([1927651,       0,       3]),
#  array([1935158,       0,      31]),
#  array([1945197,       0,       8]),
#  array([1955267,       0,       5]),
#  array([1962776,       0,      51]),
#  array([1972815,       0,       8]),
#  array([1982898,       0,       4]),
#  array([1990407,       0,      41]),
#  array([2000448,       0,       8]),
#  array([2010537,       0,       2]),
#  array([2018044,       0,      21]),
#  array([2028082,       0,       8]),
#  array([2038154,       0,       3]),
#  array([2045661,       0,      31]),
#  array([2055700,       0,       8]),
#  array([2065777,       0,       4]),
#  array([2073284,       0,      41]),
#  array([2083323,       0,       8]),
#  array([2093402,       0,       2]),
#  array([2100909,       0,      21]),
#  array([2110949,       0,       8]),
#  array([2121028,       0,       5]),
#  array([2128535,       0,      51]),
#  array([2138572,       0,       8]),
#  array([2148647,       0,       5]),
#  array([2156154,       0,      51]),
#  array([2166194,       0,       8]),
#  array([2176275,       0,       2]),
#  array([2183782,       0,      21]),
#  array([2193821,       0,       8]),
#  array([2203903,       0,       3]),
#  array([2211410,       0,      31]),
#  array([2221449,       0,       8]),
#  array([2231529,       0,       4]),
#  array([2239038,       0,      41]),
#  array([2249076,       0,       8]),
#  array([2259151,       0,       1]),
#  array([2266660,       0,      11]),
#  array([2276697,       0,       8]),
#  array([2286767,       0,       6]),
#  array([2294274,       0,      61]),
#  array([2304311,       0,       8]),
#  array([2314389,       0,       3]),
#  array([2321897,       0,      31]),
#  array([2331934,       0,       8]),
#  array([2342016,       0,       4]),
#  array([2349523,       0,      41]),
#  array([2359561,       0,       8]),
#  array([2369639,       0,       3]),
#  array([2377146,       0,      31]),
#  array([2387184,       0,       8]),
#  array([2397264,       0,       2]),
#  array([2404772,       0,      21]),
#  array([2414806,       0,       8]),
#  array([2424883,       0,       1]),
#  array([2432390,       0,      11]),
#  array([2442429,       0,       8]),
#  array([2452513,       0,       2]),
#  array([2460020,       0,      21]),
#  array([2470061,       0,       8]),
#  array([2480138,       0,       2]),
#  array([2487645,       0,      21]),
#  array([2497684,       0,       8]),
#  array([2507759,       0,       5]),
#  array([2515266,       0,      51]),
#  array([2525307,       0,       8]),
#  array([2535391,       0,       6]),
#  array([2542898,       0,      61]),
#  array([2552938,       0,       8]),
#  array([2563021,       0,       3]),
#  array([2570528,       0,      31]),
#  array([2580568,       0,       8]),
#  array([2590641,       0,       4]),
#  array([2598148,       0,      41]),
#  array([2608185,       0,       8]),
#  array([2618263,       0,       3]),
#  array([2625770,       0,      31]),
#  array([2635808,       0,       8]),
#  array([2645892,       0,       6]),
#  array([2653399,       0,      61]),
#  array([2663439,       0,       8]),
#  array([2673519,       0,       6]),
#  array([2681026,       0,      61]),
#  array([2691068,       0,       8]),
#  array([2701146,       0,       1]),
#  array([2708653,       0,      11]),
#  array([2718694,       0,       8]),
#  array([2728774,       0,       4]),
#  array([2736281,       0,      41]),
#  array([2746323,       0,       8]),
#  array([2756403,       0,       2]),
#  array([2763910,       0,      21]),
#  array([2773950,       0,       8]),
#  array([2784029,       0,       3]),
#  array([2791536,       0,      31]),
#  array([2801575,       0,       8]),
#  array([2811649,       0,       5]),
#  array([2819156,       0,      51]),
#  array([2829195,       0,       8]),
#  array([2839265,       0,       4]),
#  array([2846771,       0,      41]),
#  array([2856810,       0,       8]),
#  array([2866882,       0,       5]),
#  array([2874389,       0,      51]),
#  array([2884428,       0,       8]),
#  array([2894507,       0,       5]),
#  array([2902014,       0,      51]),
#  array([2912055,       0,       8]),
#  array([2922138,       0,       2]),
#  array([2929647,       0,      21]),
#  array([2939687,       0,       8]),
#  array([2949759,       0,       1]),
#  array([2957266,       0,      11]),
#  array([2967305,       0,       8]),
#  array([2977375,       0,       2]),
#  array([2984885,       0,      21]),
#  array([2994929,       0,       8]),
#  array([3005009,       0,       6]),
#  array([3012518,       0,      61]),
#  array([3022558,       0,       8]),
#  array([3032631,       0,       2]),
#  array([3040138,       0,      21]),
#  array([3050177,       0,       8]),
#  array([3060252,       0,       3]),
#  array([3067762,       0,      31]),
#  array([3077801,       0,       8]),
#  array([3087878,       0,       1]),
#  array([3095385,       0,      11]),
#  array([3105425,       0,       8]),
#  array([3115508,       0,       6]),
#  array([3123015,       0,      61]),
#  array([3133054,       0,       8]),
#  array([3143124,       0,       5]),
#  array([3150632,       0,      51]),
#  array([3160671,       0,       8]),
#  array([3170742,       0,       6]),
#  array([3178249,       0,      61]),
#  array([3188289,       0,       8]),
#  array([3198359,       0,       6]),
#  array([3205868,       0,      61]),
#  array([3215912,       0,       8]),
#  array([3225999,       0,       1]),
#  array([3233508,       0,      11]),
#  array([3243556,       0,       8]),
#  array([3253631,       0,       5]),
#  array([3261139,       0,      51]),
#  array([3271180,       0,       8]),
#  array([3281249,       0,       6]),
#  array([3288756,       0,      61]),
#  array([3298795,       0,       8]),
#  array([3308875,       0,       3]),
#  array([3316382,       0,      31]),
#  array([3326421,       0,       8]),
#  array([3336502,       0,       4]),
#  array([3344009,       0,      41]),
#  array([3354050,       0,       8]),
#  array([3364122,       0,       1]),
#  array([3371632,       0,      11]),
#  array([3381670,       0,       8]),
#  array([3391753,       0,       1]),
#  array([3399260,       0,      11]),
#  array([3409298,       0,       8]),
#  array([3419377,       0,       1]),
#  array([3426887,       0,      11]),
#  array([3436925,       0,       8]),
#  array([3447003,       0,       3]),
#  array([3454509,       0,      31]),
#  array([3464550,       0,       8]),
#  array([3474621,       0,       3]),
#  array([3482128,       0,      31]),
#  array([3492168,       0,       8]),
#  array([3502245,       0,       6]),
#  array([3509752,       0,      61]),
#  array([3519791,       0,       8]),
#  array([3529868,       0,       4]),
#  array([3537375,       0,      41]),
#  array([3547414,       0,       8]),
#  array([3557501,       0,       2]),
#  array([3565008,       0,      21]),
#  array([3575047,       0,       8]),
#  array([3585114,       0,       4]),
#  array([3592621,       0,      41]),
#  array([3602661,       0,       8]),
#  array([3612739,       0,       2]),
#  array([3620246,       0,      21]),
#  array([3630285,       0,       8]),
#  array([3640360,       0,       6]),
#  array([3647868,       0,      61]),
#  array([3657910,       0,       8]),
#  array([3668000,       0,       1]),
#  array([3675507,       0,      11]),
#  array([3685546,       0,       8]),
#  array([3695622,       0,       1]),
#  array([3703129,       0,      11]),
#  array([3713168,       0,       8]),
#  array([3723244,       0,       6]),
#  array([3730751,       0,      61]),
#  array([3740790,       0,       8]),
#  array([3750867,       0,       3]),
#  array([3758374,       0,      31]),
#  array([3768413,       0,       8]),
#  array([3778493,       0,       6]),
#  array([3786000,       0,      61]),
#  array([3796040,       0,       8]),
#  array([3806112,       0,       5]),
#  array([3813619,       0,      51]),
#  array([3823659,       0,       8]),
#  array([3833736,       0,       5]),
#  array([3841243,       0,      51]),
#  array([3851282,       0,       8]),
#  array([3861355,       0,       4]),
#  array([3868864,       0,      41]),
#  array([3878903,       0,       8]),
#  array([3888990,       0,       1]),
#  array([3896497,       0,      11]),
#  array([3906536,       0,       8]),
#  array([3916610,       0,       3]),
#  array([3924117,       0,      31]),
#  array([3934157,       0,       8]),
#  array([3944235,       0,       4]),
#  array([3951742,       0,      41]),
#  array([3961781,       0,       8]),
#  array([3971857,       0,       2]),
#  array([3979364,       0,      21]),
#  array([3989404,       0,       8]),
#  array([3999490,       0,       4]),
#  array([4006997,       0,      41]),
#  array([4017037,       0,       8]),
#  array([4027113,       0,       4]),
#  array([4034619,       0,      41]),
#  array([4044657,       0,       8]),
#  array([4054728,       0,       3]),
#  array([4062235,       0,      31]),
#  array([4072276,       0,       8]),
#  array([4082355,       0,       4]),
#  array([4089863,       0,      41]),
#  array([4099903,       0,       8]),
#  array([4109984,       0,       4]),
#  array([4117491,       0,      41]),
#  array([4127531,       0,       8]),
#  array([4137605,       0,       5]),
#  array([4145111,       0,      51]),
#  array([4155151,       0,       8]),
#  array([4203600,       0,   99999]),
#  array([4203600,       0,   10001]),
#  array([4214745,       0,       2]),
#  array([4222252,       0,      21]),
#  array([4232296,       0,       8]),
#  array([4242379,       0,       5]),
#  array([4249886,       0,      51]),
#  array([4259923,       0,       8]),
#  array([4269998,       0,       1]),
#  array([4277508,       0,      11]),
#  array([4287546,       0,       8]),
#  array([4297618,       0,       6]),
#  array([4305128,       0,      61]),
#  array([4315169,       0,       8]),
#  array([4325247,       0,       6]),
#  array([4332754,       0,      61]),
#  array([4342792,       0,       8]),
#  array([4352869,       0,       6]),
#  array([4360376,       0,      61]),
#  array([4370415,       0,       8]),
#  array([4380499,       0,       3]),
#  array([4388006,       0,      31]),
#  array([4398045,       0,       8]),
#  array([4408119,       0,       1]),
#  array([4415626,       0,      11]),
#  array([4425665,       0,       8]),
#  array([4435735,       0,       5]),
#  array([4443243,       0,      51]),
#  array([4453281,       0,       8]),
#  array([4463358,       0,       1]),
#  array([4470865,       0,      11]),
#  array([4480912,       0,       8]),
#  array([4490995,       0,       5]),
#  array([4498502,       0,      51]),
#  array([4508542,       0,       8]),
#  array([4518619,       0,       5]),
#  array([4526125,       0,      51]),
#  array([4536166,       0,       8]),
#  array([4546242,       0,       1]),
#  array([4553751,       0,      11]),
#  array([4563790,       0,       8]),
#  array([4573870,       0,       3]),
#  array([4581377,       0,      31]),
#  array([4591417,       0,       8]),
#  array([4601490,       0,       5]),
#  array([4608997,       0,      51]),
#  array([4619037,       0,       8]),
#  array([4629109,       0,       3]),
#  array([4636616,       0,      31]),
#  array([4646656,       0,       8]),
#  array([4656726,       0,       3]),
#  array([4664233,       0,      31]),
#  array([4674280,       0,       8]),
#  array([4684369,       0,       6]),
#  array([4691876,       0,      61]),
#  array([4701914,       0,       8]),
#  array([4711994,       0,       2]),
#  array([4719501,       0,      21]),
#  array([4729540,       0,       8]),
#  array([4739619,       0,       5]),
#  array([4747126,       0,      51]),
#  array([4757165,       0,       8]),
#  array([4767245,       0,       5]),
#  array([4774752,       0,      51]),
#  array([4784790,       0,       8]),
#  array([4794874,       0,       5]),
#  array([4802382,       0,      51]),
#  array([4812420,       0,       8]),
#  array([4822492,       0,       4]),
#  array([4829999,       0,      41]),
#  array([4840038,       0,       8]),
#  array([4850117,       0,       1]),
#  array([4857627,       0,      11]),
#  array([4867666,       0,       8]),
#  array([4877738,       0,       2]),
#  array([4885248,       0,      21]),
#  array([4895288,       0,       8]),
#  array([4905374,       0,       4]),
#  array([4912881,       0,      41]),
#  array([4922921,       0,       8]),
#  array([4932992,       0,       5]),
#  array([4940499,       0,      51]),
#  array([4950538,       0,       8]),
#  array([4960613,       0,       2]),
#  array([4968120,       0,      21]),
#  array([4978158,       0,       8]),
#  array([4988239,       0,       2]),
#  array([4995746,       0,      21]),
#  array([5005787,       0,       8]),
#  array([5015871,       0,       5]),
#  array([5023377,       0,      51]),
#  array([5033418,       0,       8]),
#  array([5043490,       0,       6]),
#  array([5050997,       0,      61]),
#  array([5061036,       0,       8]),
#  array([5071113,       0,       2]),
#  array([5078620,       0,      21]),
#  array([5088660,       0,       8]),
#  array([5098735,       0,       2]),
#  array([5106242,       0,      21]),
#  array([5116281,       0,       8]),
#  array([5126364,       0,       3]),
#  array([5133871,       0,      31]),
#  array([5143908,       0,       8]),
#  array([5153982,       0,       3]),
#  array([5161489,       0,      31]),
#  array([5171526,       0,       8]),
#  array([5181602,       0,       4]),
#  array([5189109,       0,      41]),
#  array([5199146,       0,       8]),
#  array([5209227,       0,       4]),
#  array([5216734,       0,      41]),
#  array([5226772,       0,       8]),
#  array([5236852,       0,       3]),
#  array([5244362,       0,      31]),
#  array([5254403,       0,       8]),
#  array([5264482,       0,       4]),
#  array([5271989,       0,      41]),
#  array([5282028,       0,       8]),
#  array([5292106,       0,       2]),
#  array([5299614,       0,      21]),
#  array([5309653,       0,       8]),
#  array([5319730,       0,       5]),
#  array([5327237,       0,      51]),
#  array([5337276,       0,       8]),
#  array([5347362,       0,       1]),
#  array([5354869,       0,      11]),
#  array([5364908,       0,       8]),
#  array([5374981,       0,       4]),
#  array([5382488,       0,      41]),
#  array([5392530,       0,       8]),
#  array([5402605,       0,       3]),
#  array([5410115,       0,      31]),
#  array([5420159,       0,       8]),
#  array([5430231,       0,       3]),
#  array([5437737,       0,      31]),
#  array([5447778,       0,       8]),
#  array([5457857,       0,       5]),
#  array([5465364,       0,      51]),
#  array([5475406,       0,       8]),
#  array([5485479,       0,       4]),
#  array([5492987,       0,      41]),
#  array([5503026,       0,       8]),
#  array([5513100,       0,       2]),
#  array([5520608,       0,      21]),
#  array([5530648,       0,       8]),
#  array([5540730,       0,       5]),
#  array([5548237,       0,      51]),
#  array([5558277,       0,       8]),
#  array([5568364,       0,       5]),
#  array([5575871,       0,      51]),
#  array([5585910,       0,       8]),
#  array([5595984,       0,       4]),
#  array([5603491,       0,      41]),
#  array([5613530,       0,       8]),
#  array([5623602,       0,       1]),
#  array([5631109,       0,      11]),
#  array([5641148,       0,       8]),
#  array([5651221,       0,       3]),
#  array([5658728,       0,      31]),
#  array([5668771,       0,       8]),
#  array([5678852,       0,       1]),
#  array([5686358,       0,      11]),
#  array([5696401,       0,       8]),
#  array([5706473,       0,       1]),
#  array([5713980,       0,      11]),
#  array([5724020,       0,       8]),
#  array([5734097,       0,       4]),
#  array([5741603,       0,      41]),
#  array([5751642,       0,       8]),
#  array([5761723,       0,       4]),
#  array([5769229,       0,      41]),
#  array([5779271,       0,       8]),
#  array([5789350,       0,       2]),
#  array([5796857,       0,      21]),
#  array([5806895,       0,       8]),
#  array([5816969,       0,       2]),
#  array([5824476,       0,      21]),
#  array([5834515,       0,       8]),
#  array([5844591,       0,       3]),
#  array([5852099,       0,      31]),
#  array([5862138,       0,       8]),
#  array([5872218,       0,       2]),
#  array([5879725,       0,      21]),
#  array([5889762,       0,       8]),
#  array([5899841,       0,       6]),
#  array([5907348,       0,      61]),
#  array([5917385,       0,       8]),
#  array([5927455,       0,       5]),
#  array([5934962,       0,      51]),
#  array([5945000,       0,       8]),
#  array([5955069,       0,       3]),
#  array([5962579,       0,      31]),
#  array([5972623,       0,       8]),
#  array([5982698,       0,       3]),
#  array([5990205,       0,      31]),
#  array([6000250,       0,       8]),
#  array([6010333,       0,       3]),
#  array([6017840,       0,      31]),
#  array([6027882,       0,       8]),
#  array([6037965,       0,       6]),
#  array([6045472,       0,      61]),
#  array([6055512,       0,       8]),
#  array([6065588,       0,       4]),
#  array([6073095,       0,      41]),
#  array([6083135,       0,       8]),
#  array([6093219,       0,       1]),
#  array([6100726,       0,      11]),
#  array([6110765,       0,       8]),
#  array([6120842,       0,       4]),
#  array([6128349,       0,      41]),
#  array([6138386,       0,       8]),
#  array([6148459,       0,       6]),
#  array([6155965,       0,      61]),
#  array([6166004,       0,       8]),
#  array([6176084,       0,       5]),
#  array([6183592,       0,      51]),
#  array([6193631,       0,       8]),
#  array([6203707,       0,       3]),
#  array([6211214,       0,      31]),
#  array([6221254,       0,       8]),
#  array([6231339,       0,       3]),
#  array([6238846,       0,      31]),
#  array([6248887,       0,       8]),
#  array([6258958,       0,       5]),
#  array([6266465,       0,      51]),
#  array([6276504,       0,       8]),
#  array([6286583,       0,       2]),
#  array([6294093,       0,      21]),
#  array([6304131,       0,       8]),
#  array([6314207,       0,       3]),
#  array([6321713,       0,      31]),
#  array([6331752,       0,       8]),
#  array([6341830,       0,       2]),
#  array([6349337,       0,      21]),
#  array([6359379,       0,       8]),
#  array([6369459,       0,       6]),
#  array([6376969,       0,      61]),
#  array([6387007,       0,       8]),
#  array([6397080,       0,       4]),
#  array([6404587,       0,      41]),
#  array([6414628,       0,       8]),
#  array([6424706,       0,       3]),
#  array([6432213,       0,      31]),
#  array([6442252,       0,       8]),
#  array([6452333,       0,       5]),
#  array([6459841,       0,      51]),
#  array([6469881,       0,       8]),
#  array([6479956,       0,       4]),
#  array([6487463,       0,      41]),
#  array([6497504,       0,       8]),
#  array([6507577,       0,       1]),
#  array([6515084,       0,      11]),
#  array([6525124,       0,       8]),
#  array([6535205,       0,       2]),
#  array([6542712,       0,      21]),
#  array([6552753,       0,       8]),
#  array([6562834,       0,       6]),
#  array([6570341,       0,      61]),
#  array([6580381,       0,       8]),
#  array([6590452,       0,       1]),
#  array([6597959,       0,      11]),
#  array([6607998,       0,       8]),
#  array([6618075,       0,       4]),
#  array([6625582,       0,      41]),
#  array([6635621,       0,       8]),
#  array([6645699,       0,       5]),
#  array([6653209,       0,      51]),
#  array([6663248,       0,       8]),
#  array([6673328,       0,       6]),
#  array([6680838,       0,      61]),
#  array([6690877,       0,       8]),
#  array([6700949,       0,       5]),
#  array([6708456,       0,      51]),
#  array([6718496,       0,       8]),
#  array([6728583,       0,       6]),
#  array([6736090,       0,      61]),
#  array([6746128,       0,       8]),
#  array([6756200,       0,       5]),
#  array([6763707,       0,      51]),
#  array([6773749,       0,       8]),
#  array([6783826,       0,       4]),
#  array([6791333,       0,      41]),
#  array([6801372,       0,       8]),
#  array([6811443,       0,       6]),
#  array([6818953,       0,      61]),
#  array([6828996,       0,       8]),
#  array([6839069,       0,       6]),
#  array([6846576,       0,      61]),
#  array([6856616,       0,       8]),
#  array([6866693,       0,       4]),
#  array([6874203,       0,      41]),
#  array([6884242,       0,       8]),
#  array([6894324,       0,       4]),
#  array([6901831,       0,      41]),
#  array([6911870,       0,       8]),
#  array([6921944,       0,       5]),
#  array([6929455,       0,      51]),
#  array([6939494,       0,       8]),
#  array([6949566,       0,       3]),
#  array([6957073,       0,      31]),
#  array([6967112,       0,       8]),
#  array([6977191,       0,       3]),
#  array([6984698,       0,      31]),
#  array([6994738,       0,       8]),
#  array([7004820,       0,       4]),
#  array([7012327,       0,      41]),
#  array([7022372,       0,       8]),
#  array([7032447,       0,       6]),
#  array([7039954,       0,      61]),
#  array([7049997,       0,       8]),
#  array([7060069,       0,       6]),
#  array([7067576,       0,      61]),
#  array([7077614,       0,       8]),
#  array([7087687,       0,       1]),
#  array([7095193,       0,      11]),
#  array([7105231,       0,       8]),
#  array([7115312,       0,       1]),
#  array([7122822,       0,      11]),
#  array([7132862,       0,       8]),
#  array([7142939,       0,       6]),
#  array([7150446,       0,      61]),
#  array([7160485,       0,       8]),
#  array([7170560,       0,       1]),
#  array([7178068,       0,      11]),
#  array([7188106,       0,       8]),
#  array([7198190,       0,       2]),
#  array([7205696,       0,      21]),
#  array([7215738,       0,       8]),
#  array([7225816,       0,       1]),
#  array([7233323,       0,      11]),
#  array([7243362,       0,       8]),
#  array([7253435,       0,       3]),
#  array([7260942,       0,      31]),
#  array([7270988,       0,       8]),
#  array([7281059,       0,       6]),
#  array([7288569,       0,      61]),
#  array([7298608,       0,       8]),
#  array([7308680,       0,       2]),
#  array([7316186,       0,      21]),
#  array([7326226,       0,       8]),
#  array([7336307,       0,       1]),
#  array([7343813,       0,      11]),
#  array([7353852,       0,       8]),
#  array([7363927,       0,       6]),
#  array([7371433,       0,      61]),
#  array([7381473,       0,       8]),
#  array([7391553,       0,       1]),
#  array([7399060,       0,      11]),
#  array([7409099,       0,       8]),
#  array([7419183,       0,       4]),
#  array([7426690,       0,      41]),
#  array([7436730,       0,       8]),
#  array([7446811,       0,       6]),
#  array([7454318,       0,      61]),
#  array([7464357,       0,       8]),
#  array([7474432,       0,       4]),
#  array([7481939,       0,      41]),
#  array([7491980,       0,       8]),
#  array([7502053,       0,       3]),
#  array([7509560,       0,      31]),
#  array([7519599,       0,       8]),
#  array([7529679,       0,       2]),
#  array([7537186,       0,      21]),
#  array([7547225,       0,       8]),
#  array([7557306,       0,       5]),
#  array([7564813,       0,      51]),
#  array([7574852,       0,       8]),
#  array([7584928,       0,       6]),
#  array([7592435,       0,      61]),
#  array([7602474,       0,       8]),
#  array([7612550,       0,       5]),
#  array([7620056,       0,      51]),
#  array([7630093,       0,       8]),
#  array([7640172,       0,       3]),
#  array([7647679,       0,      31]),
#  array([7657718,       0,       8]),
#  array([7667802,       0,       2]),
#  array([7675308,       0,      21]),
#  array([7685348,       0,       8]),
#  array([7695429,       0,       2]),
#  array([7702936,       0,      21]),
#  array([7712975,       0,       8]),
#  array([7723047,       0,       6]),
#  array([7730554,       0,      61]),
#  array([7740593,       0,       8]),
#  array([7750673,       0,       6]),
#  array([7758180,       0,      61]),
#  array([7768219,       0,       8]),
#  array([7778303,       0,       2]),
#  array([7785813,       0,      21]),
#  array([7795852,       0,       8]),
#  array([7805926,       0,       4]),
#  array([7813432,       0,      41]),
#  array([7823472,       0,       8]),
#  array([7833545,       0,       4]),
#  array([7841052,       0,      41]),
#  array([7851091,       0,       8]),
#  array([7861172,       0,       1]),
#  array([7868679,       0,      11]),
#  array([7878718,       0,       8]),
#  array([7888801,       0,       5]),
#  array([7896308,       0,      51]),
#  array([7906348,       0,       8]),
#  array([7916419,       0,       5]),
#  array([7923926,       0,      51]),
#  array([7933972,       0,       8]),
#  array([7944043,       0,       1]),
#  array([7951550,       0,      11]),
#  array([7961590,       0,       8]),
#  array([7971668,       0,       3]),
#  array([7979175,       0,      31]),
#  array([7989214,       0,       8]),
#  array([7999296,       0,       4]),
#  array([8006803,       0,      41]),
#  array([8016840,       0,       8]),
#  array([8026919,       0,       6]),
#  array([8034426,       0,      61]),
#  array([8044466,       0,       8]),
#  array([8054538,       0,       1]),
#  array([8062045,       0,      11]),
#  array([8072084,       0,       8]),
#  array([8082162,       0,       3]),
#  array([8089669,       0,      31]),
#  array([8099709,       0,       8]),
#  array([8109788,       0,       3]),
#  array([8117295,       0,      31]),
#  array([8127334,       0,       8]),
#  array([8137409,       0,       5]),
#  array([8144916,       0,      51]),
#  array([8154956,       0,       8]),
#  array([8165031,       0,       1]),
#  array([8172538,       0,      11]),
#  array([8182578,       0,       8]),
#  array([8192664,       0,       2]),
#  array([8200171,       0,      21]),
#  array([8210210,       0,       8]),
#  array([8220292,       0,       2]),
#  array([8227799,       0,      21]),
#  array([8237838,       0,       8]),
#  array([8247913,       0,       1]),
#  array([8255419,       0,      11]),
#  array([8265459,       0,       8]),
#  array([8275537,       0,       1]),
#  array([8283045,       0,      11]),
#  array([8293084,       0,       8]),
#  array([8303159,       0,       6]),
#  array([8310670,       0,      61]),
#  array([8320708,       0,       8]),
#  array([8330786,       0,       5]),
#  array([8338293,       0,      51]),
#  array([8348332,       0,       8]),
#  array([8358405,       0,       2]),
#  array([8365912,       0,      21]),
#  array([8375951,       0,       8]),
#  array([8380958,       0,      14])]

# %%
selected_events = mne.pick_events(events[0], exclude=[99999,10001,10002,10003,1,2,3,4,5,6,13,14])
selected_events
# Out:
# array([[  56489,       0,      41],
#        [  66533,       0,       8],
#        [  84137,       0,      31],
#        ...,
#        [8348332,       0,       8],
#        [8365912,       0,      21],
#        [8375951,       0,       8]])

# %%
selected_events.shape
# Out:
# (600, 3)

# %%
mne.viz.plot_events(selected_events[:100]);

# %%
event_ids = {'Stimulus/S 11': 11,'Stimulus/S 21': 21,'Stimulus/S 31': 31,'Stimulus/S 41': 41,'Stimulus/S 51': 51,'Stimulus/S 61': 61}
epochs = mne.Epochs(raw, events=selected_events, event_id=event_ids, tmin=0, tmax=7, preload=True,baseline=(0, 0))
# Out:
# Not setting metadata
# 300 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 17501 original time points ...
# 0 bad epochs dropped

# %%
epochs
# Out:
# <Epochs |  300 events (all good), 0 - 7 sec, baseline 0 – 0 sec, ~1.41 GB, data loaded,
#  'Stimulus/S 11': 50
#  'Stimulus/S 21': 50
#  'Stimulus/S 31': 50
#  'Stimulus/S 41': 50
#  'Stimulus/S 51': 50
#  'Stimulus/S 61': 50>

# %%
epochs.get_data().shape
# Out:
# (300, 36, 17501)

# %%
epochs.crop(tmin=3,tmax=7,include_tmax=True)
epochs.get_data().shape
# Out:
# (300, 36, 10001)

# %%
# rest_epochs = mne.Epochs(raw, events=selected_events, event_id={'Stimulus/S 8': 8}, tmin=0, tmax=4, preload=True,baseline=(0, 0))
# print('=' * 40)
# rest_epochs.get_data().shape

# %% [markdown]
# ### Epochs Downsampling

# %%
epochs.resample(sfreq=1250)
epochs.get_data().shape
# Out:
# (300, 36, 5000)

# %%
# rest_epochs.resample(sfreq=1250)
# rest_epochs.get_data().shape

# %%
# epochs.plot(n_epochs=5);

# %%
# rest_epochs.plot(n_epochs=5);

# %% [markdown]
# ### Repairing artifacts with ICA
# Note : ICA fitting is not deterministic (e.g., the components may get a sign flip on different runs, or may not always be returned in the same order), so we’ll also specify a random seed so that we get identical results each time this tutorial is built by our web servers

# %% [markdown]
# ### First ,  on main classes epochs

# %%
# ica = mne.preprocessing.ICA(n_components=20, max_iter='auto',random_state=0,method='infomax')
# ica.fit(epochs.copy())

# %%
# ica.plot_components();

# %%
# # use automatic detection
# bad_indx,scores = ica.find_bads_eog(raw,ch_name=["hEOG_L","hEOG_R","vEOG_U","vEOG_D"],threshold=2)
# print(bad_indx)

# %%
# epochs.plot(n_epochs=5);

# %%
# ica.exclude = bad_indx
# ica.apply(epochs.copy(),exclude=ica.exclude).plot(n_epochs=5);

# %%
# ica.apply(epochs,exclude=ica.exclude)

# %% [markdown]
# ### Second ,  on rest_epochs

# %%
# ica = mne.preprocessing.ICA(n_components=20, max_iter='auto',random_state=0,method='fastica')
# ica.fit(rest_epochs.copy())

# %%
# ica.plot_components();

# %%
# # use automatic detection
# bad_indx,scores = ica.find_bads_eog(raw,ch_name=["hEOG_L","hEOG_R","vEOG_U","vEOG_D"],threshold=2)
# print(bad_indx)

# %%
# rest_epochs.plot(n_epochs=5);

# %%
# ica.exclude = [2,3,6,13,0,19]
# ica.apply(epochs.copy(),exclude=ica.exclude).plot(n_epochs=5);

# %%
# ica.apply(rest_epochs,exclude=ica.exclude)

# %% [markdown]
# ### Repairing artifacts with regression
# Remove EOG artifact signals from other channels by regression.

# %%
# # plotting before
# # plot the evoked for the EEG and the EOG sensors
# fig = epochs.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# # Perform regression using the EOG sensor as independent variable and the EEG
# # sensors as dependent variables.
# model_plain = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(epochs)
# fig = model_plain.plot(vlim=(None, 0.4))  # regression coefficients as topomap
# fig.set_size_inches(3, 2);

# %%
# epochs_clean_plain = model_plain.apply(epochs)
# # After regression, we should redo the baseline correction
# epochs_clean_plain.apply_baseline(baseline=(3, 7))
# # Show the evoked potential computed on the corrected data
# fig = epochs_clean_plain.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# # create epochs with the evoked subtracted out
# epochs_sub = epochs.copy().subtract_evoked()

# # perform regression
# model_sub = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(epochs_sub)
# fig = model_sub.plot(vlim=(None, 0.4))
# fig.set_size_inches(3, 2)

# # apply the regression coefficients to the original epochs
# epochs_clean_sub = model_plain.apply(epochs).apply_baseline(baseline=(3, 7))
# fig = epochs_clean_sub.average('all').plot()
# fig.set_size_inches(6, 6)

# %%
# eog_epochs = mne.preprocessing.create_eog_epochs(raw)
# # We need to explicitly specify that we want to average the EOG channel too.
# eog_evoked = eog_epochs.average('all')
# eog_evoked.plot('all')
# fig.set_size_inches(6, 6)

# # perform regression on the evoked blink response
# model_evoked = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog').fit(eog_evoked)
# fig = model_evoked.plot(vlim=(None, 0.4))
# fig.set_size_inches(3, 2)

# # apply the regression coefficients to the original epochs
# epochs_clean_evoked = model_evoked.apply(epochs).apply_baseline(baseline=(3, 7))
# fig = epochs_clean_evoked.average('all').plot()
# fig.set_size_inches(6, 6)

# # for good measure, also show the effect on the blink evoked
# eog_evoked_clean = model_evoked.apply(eog_evoked)
# eog_evoked_clean.apply_baseline(baseline=(0, 0))
# eog_evoked_clean.plot('all')
# fig.set_size_inches(6, 6)

# %%
# order = np.concatenate([  # plotting order: EOG first, then EEG
#     mne.pick_types(raw.info, meg=False, eog=True),
#     mne.pick_types(raw.info, meg=False, eeg=True),
# ])
# raw_kwargs = dict(events=eog_epochs.events, order=order, start=13, duration=3,
#                   n_channels=10, scalings=dict(eeg=50e-6, eog=250e-6))

# # plot original data
# raw.plot(**raw_kwargs);

# # regress (using coefficients computed previously) and plot
# raw_clean = model_evoked.apply(raw)
# raw_clean.plot(**raw_kwargs);

# %%
# epochs.apply_baseline((None,0))

# %%
# epochs["Stimulus/S 41"].plot_image(picks=[5]); # picks=[channel index]

# %%
# epochs.equalize_event_counts(event_ids)
# epochs

# %% [markdown]
# ### DWT

# %%
epochs.plot(n_epochs=1);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import pywt
from pywt import wavedec
coeffs = wavedec(epochs, 'db4' , level=5)
len(coeffs)
# Out:
# 6

# %%
coeffs_ = np.array(coeffs[5])
coeffs_.shape
# Out:
# (300, 36, 2503)

# %%
mean_amplitude = np.mean(coeffs_)

# %% [markdown]
# ### data in time domain

# %%
epochs.pick_types(eeg=True)
data = epochs.get_data()
# rest_epochs.pick_types(eeg=True)
# classes_data = epochs.get_data()
# rest_data = rest_epochs.get_data()

# %%
# data = np.empty(shape=(600,32,5000))
# data[0:300] = classes_data
# data[300:600] = rest_data

# %%
labels = np.empty(shape=(300))
decode = {11: 0, 21: 1, 31: 2, 41:3, 51: 4, 61: 5, 8 :6}
k=0
for i in epochs.events:
    labels[k]=decode[i[2]]
    k+=1

# %%
data.shape
# Out:
# (300, 32, 5000)

# %%
# for i in range(300,600):
#     labels[i] = 6
labels.shape
# Out:
# (300,)

# %%
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size = 0.2,stratify=labels,shuffle=True)

# %%
# ind = np.argsort(y_train)
# y_train = y_train[ind]
# X_train = X_train[ind]

# %%
# ind = np.argsort(y_val)
# y_val = y_val[ind]
# X_val = X_val[ind]

# %%
y_train=tf.keras.utils.to_categorical(y_train,num_classes=6) 
y_val=tf.keras.utils.to_categorical(y_val,num_classes=6)

# %%
# Normaliation
# X_train = MinMaxScaler().fit_transform(X_train)
# X_val = MinMaxScaler().fit_transform(X_val)
# X_train = (X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train))
# X_val = (X_val-np.min(X_val))/(np.max(X_val)-np.min(X_val))

# %%
# def preprocess_input(eeg_signals):
#     eeg_signals_3d = np.zeros((eeg_signals.shape[0], 32, 2500, 3))
#     for i in range(eeg_signals.shape[0]):
#         trial_3d = np.dstack([eeg_signals[0],eeg_signals[0],eeg_signals[0]])
#         eeg_signals_3d[i] = trial_3d
#     return eeg_signals_3d
# X_train = preprocess_input(X_train)
# X_val = preprocess_input(X_val)

# %%
print('X_train: ',X_train.shape)
print('X_val:   ',X_val.shape)
print('y_train: ',y_train.shape)
print('y_val:   ',y_val.shape)
# Out:
# X_train:  (240, 32, 5000)
# X_val:    (60, 32, 5000)
# y_train:  (240, 6)
# y_val:    (60, 6)

# %% [markdown]
# ## Model CNN

# %%
from EEGModels import EEGNet 
model = EEGNet(nb_classes=6, Chans = 32, Samples = 5000, dropoutRate = 0.2, kernLength = 64, F1 = 8, D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout')

# %%
model.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.,
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
# model = tf.keras.models.load_model('model.h5')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 10001, 1)]    0
#
#  conv2d (Conv2D)             (None, 32, 10001, 8)      512
#
#  batch_normalization (BatchN  (None, 32, 10001, 8)     32
#  ormalization)
#
#  depthwise_conv2d (Depthwise  (None, 1, 10001, 16)     512
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 1, 10001, 16)     64
#  hNormalization)
#
#  activation (Activation)     (None, 1, 10001, 16)      0
#
#  average_pooling2d (AverageP  (None, 1, 2500, 16)      0
#  ooling2D)
#
#  dropout (Dropout)           (None, 1, 2500, 16)       0
#
#  separable_conv2d (Separable  (None, 1, 2500, 16)      512
#  Conv2D)
#
#  batch_normalization_2 (Batc  (None, 1, 2500, 16)      64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1, 2500, 16)       0
#
#  average_pooling2d_1 (Averag  (None, 1, 312, 16)       0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 312, 16)        0
#
#  flatten (Flatten)           (None, 4992)              0
#
#  dense (Dense)               (None, 6)                 29958
#
#  softmax (Activation)        (None, 6)                 0
#
# =================================================================
# Total params: 31,654
# Trainable params: 31,574
# Non-trainable params: 80
# _________________________________________________________________

# %%
Epochs=40
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                     batch_size=32,
                     verbose=1)         #,callbacks=[early_stopping]
# Out:
# Epoch 1/40
# 8/8 [==============================] - 20s 2s/step - loss: 1.9039 - accuracy: 0.1583 - val_loss: 1.7948 - val_accuracy: 0.1667
# Epoch 2/40
# 8/8 [==============================] - 19s 2s/step - loss: 1.8801 - accuracy: 0.2083 - val_loss: 1.8011 - val_accuracy: 0.1667
# Epoch 3/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.6795 - accuracy: 0.3583 - val_loss: 1.8015 - val_accuracy: 0.1667
# Epoch 4/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.5595 - accuracy: 0.4042 - val_loss: 1.7979 - val_accuracy: 0.1667
# Epoch 5/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.4129 - accuracy: 0.5292 - val_loss: 1.7977 - val_accuracy: 0.1667
# Epoch 6/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.3376 - accuracy: 0.6208 - val_loss: 1.7984 - val_accuracy: 0.1667
# Epoch 7/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.2771 - accuracy: 0.6833 - val_loss: 1.7993 - val_accuracy: 0.1333
# Epoch 8/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.2372 - accuracy: 0.7708 - val_loss: 1.7989 - val_accuracy: 0.1500
# Epoch 9/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.2164 - accuracy: 0.7625 - val_loss: 1.8012 - val_accuracy: 0.1167
# Epoch 10/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.2199 - accuracy: 0.7458 - val_loss: 1.8021 - val_accuracy: 0.1833
# Epoch 11/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1883 - accuracy: 0.7625 - val_loss: 1.8038 - val_accuracy: 0.1333
# Epoch 12/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1863 - accuracy: 0.7792 - val_loss: 1.8027 - val_accuracy: 0.2000
# Epoch 13/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1621 - accuracy: 0.7958 - val_loss: 1.8079 - val_accuracy: 0.1667
# Epoch 14/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1514 - accuracy: 0.8292 - val_loss: 1.8110 - val_accuracy: 0.1833
# Epoch 15/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1657 - accuracy: 0.7500 - val_loss: 1.8147 - val_accuracy: 0.1833
# Epoch 16/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1518 - accuracy: 0.7917 - val_loss: 1.8027 - val_accuracy: 0.1833
# Epoch 17/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1188 - accuracy: 0.8458 - val_loss: 1.8075 - val_accuracy: 0.1833
# Epoch 18/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1189 - accuracy: 0.8375 - val_loss: 1.8201 - val_accuracy: 0.2000
# Epoch 19/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1133 - accuracy: 0.8333 - val_loss: 1.8172 - val_accuracy: 0.2167
# Epoch 20/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.1029 - accuracy: 0.8125 - val_loss: 1.8250 - val_accuracy: 0.2667
# Epoch 21/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0918 - accuracy: 0.8417 - val_loss: 1.8304 - val_accuracy: 0.1833
# Epoch 22/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0995 - accuracy: 0.7958 - val_loss: 1.8289 - val_accuracy: 0.2000
# Epoch 23/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0704 - accuracy: 0.8542 - val_loss: 1.8387 - val_accuracy: 0.1833
# Epoch 24/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.0642 - accuracy: 0.8667 - val_loss: 1.8356 - val_accuracy: 0.2500
# Epoch 25/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0468 - accuracy: 0.8750 - val_loss: 1.8323 - val_accuracy: 0.2333
# Epoch 26/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0389 - accuracy: 0.8292 - val_loss: 1.8435 - val_accuracy: 0.2167
# Epoch 27/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0638 - accuracy: 0.8167 - val_loss: 1.8439 - val_accuracy: 0.2333
# Epoch 28/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0743 - accuracy: 0.8250 - val_loss: 1.8582 - val_accuracy: 0.2500
# Epoch 29/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0363 - accuracy: 0.8292 - val_loss: 1.8719 - val_accuracy: 0.2333
# Epoch 30/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0312 - accuracy: 0.8750 - val_loss: 1.8736 - val_accuracy: 0.2167
# Epoch 31/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.0172 - accuracy: 0.8458 - val_loss: 1.8850 - val_accuracy: 0.2000
# Epoch 32/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.0439 - accuracy: 0.8250 - val_loss: 1.8554 - val_accuracy: 0.2500
# Epoch 33/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0732 - accuracy: 0.8125 - val_loss: 1.8940 - val_accuracy: 0.2333
# Epoch 34/40
# 8/8 [==============================] - 18s 2s/step - loss: 1.0066 - accuracy: 0.8750 - val_loss: 1.8957 - val_accuracy: 0.3000
# Epoch 35/40
# 8/8 [==============================] - 17s 2s/step - loss: 1.0179 - accuracy: 0.8500 - val_loss: 1.9015 - val_accuracy: 0.1667
# Epoch 36/40
# 8/8 [==============================] - 17s 2s/step - loss: 0.9929 - accuracy: 0.8958 - val_loss: 1.9584 - val_accuracy: 0.2000
# Epoch 37/40
# 8/8 [==============================] - 17s 2s/step - loss: 0.9886 - accuracy: 0.8667 - val_loss: 1.9241 - val_accuracy: 0.1833
# Epoch 38/40
# 8/8 [==============================] - 17s 2s/step - loss: 0.9744 - accuracy: 0.8958 - val_loss: 1.9734 - val_accuracy: 0.1833
# Epoch 39/40
# 8/8 [==============================] - 18s 2s/step - loss: 0.9621 - accuracy: 0.9125 - val_loss: 2.0203 - val_accuracy: 0.2000
# Epoch 40/40
# 8/8 [==============================] - 17s 2s/step - loss: 0.9510 - accuracy: 0.8917 - val_loss: 2.0388 - val_accuracy: 0.1000

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(X_train,y_train)
# Out:
# 8/8 [==============================] - 1s 169ms/step - loss: 1.4888 - accuracy: 0.6083
# [1.4888027906417847, 0.6083333492279053]

# %%
model.evaluate(X_val,y_val)
# Out:
# 2/2 [==============================] - 0s 171ms/step - loss: 2.0388 - accuracy: 0.1000
# [2.038753032684326, 0.10000000149011612]

# %%
model.save('model.h5')

# %% [markdown]
# ## Model 2

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(32,10001)),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(256, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model2.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 30, 64)            1920256
#
#  max_pooling1d_3 (MaxPooling  (None, 15, 64)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 13, 128)           24704
#
#  max_pooling1d_4 (MaxPooling  (None, 6, 128)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 4, 256)            98560
#
#  max_pooling1d_5 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 2,309,254
# Trainable params: 2,309,254
# Non-trainable params: 0
# _________________________________________________________________

# %%
Epochs=40
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model2.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                     batch_size=32,
                     verbose=1)         #,callbacks=[early_stopping]
# Out:
# Epoch 1/40
# 8/8 [==============================] - 1s 127ms/step - loss: 1.7921 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 2/40
# 8/8 [==============================] - 1s 99ms/step - loss: 1.7919 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 3/40
# 8/8 [==============================] - 1s 94ms/step - loss: 1.7920 - accuracy: 0.1625 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 4/40
# 8/8 [==============================] - 1s 99ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 5/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7922 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 6/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1500
# Epoch 7/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7923 - accuracy: 0.1667 - val_loss: 1.7919 - val_accuracy: 0.1667
# Epoch 8/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7921 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 9/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7922 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 10/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7921 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1500
# Epoch 11/40
# 8/8 [==============================] - 1s 95ms/step - loss: 1.7922 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 12/40
# 8/8 [==============================] - 1s 97ms/step - loss: 1.7919 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 13/40
# 8/8 [==============================] - 1s 100ms/step - loss: 1.7919 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 14/40
# 8/8 [==============================] - 1s 102ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 15/40
# 8/8 [==============================] - 1s 107ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 16/40
# 8/8 [==============================] - 1s 97ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 17/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7924 - accuracy: 0.1583 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 18/40
# 8/8 [==============================] - 1s 97ms/step - loss: 1.7921 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1833
# Epoch 19/40
# 8/8 [==============================] - 1s 100ms/step - loss: 1.7922 - accuracy: 0.1417 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 20/40
# 8/8 [==============================] - 1s 98ms/step - loss: 1.7921 - accuracy: 0.1500 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 21/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1833
# Epoch 22/40
# 8/8 [==============================] - 1s 91ms/step - loss: 1.7921 - accuracy: 0.1458 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 23/40
# 8/8 [==============================] - 1s 94ms/step - loss: 1.7921 - accuracy: 0.1542 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 24/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7923 - accuracy: 0.1625 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 25/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 26/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7919 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 27/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 28/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7921 - accuracy: 0.1458 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 29/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7921 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 30/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7919 - accuracy: 0.1542 - val_loss: 1.7918 - val_accuracy: 0.1833
# Epoch 31/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 32/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 33/40
# 8/8 [==============================] - 1s 91ms/step - loss: 1.7920 - accuracy: 0.1458 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 34/40
# 8/8 [==============================] - 1s 91ms/step - loss: 1.7920 - accuracy: 0.1500 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 35/40
# 8/8 [==============================] - 1s 98ms/step - loss: 1.7919 - accuracy: 0.1500 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 36/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7920 - accuracy: 0.1750 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 37/40
# 8/8 [==============================] - 1s 92ms/step - loss: 1.7920 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 38/40
# 8/8 [==============================] - 1s 93ms/step - loss: 1.7919 - accuracy: 0.1375 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 39/40
# 8/8 [==============================] - 1s 91ms/step - loss: 1.7921 - accuracy: 0.1292 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 40/40
# 8/8 [==============================] - 1s 89ms/step - loss: 1.7919 - accuracy: 0.1375 - val_loss: 1.7918 - val_accuracy: 0.1667

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model2.evaluate(X_train,y_train)
# Out:
# 8/8 [==============================] - 0s 26ms/step - loss: 1.7918 - accuracy: 0.1667
# [1.7918027639389038, 0.1666666716337204]

# %%
model2.evaluate(X_val,y_val)
# Out:
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7918 - accuracy: 0.1667
# [1.7918095588684082, 0.1666666716337204]

# %% [markdown]
# ## Model 3

# %%
ResNet50 = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(32, 10001, 3),
)

# %%
model = tf.keras.models.Sequential([
    ResNet50,
    # tf.keras.layers.Flatten(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1024, activation='relu'),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(6,activation='softmax')
])

# %%
model.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 79, 2048)       23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1024)              2098176
#
#  dense_7 (Dense)             (None, 6)                 6150
#
# =================================================================
# Total params: 25,692,038
# Trainable params: 25,638,918
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
Epochs=40
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                    batch_size=32,
                    verbose=1)#,callbacks=[early_stopping]
# Out:
# Epoch 1/100
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x0000028802783940>
# Traceback (most recent call last):
#   File "c:\Users\mohamed\anaconda3-folder\anaconda3\lib\weakref.py", line 371, in remove
#     self = selfref()
# KeyboardInterrupt:
